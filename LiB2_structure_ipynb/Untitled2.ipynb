# %%
# -*- coding: utf-8 -*-
import logging
import numpy as np
from ase import units
from ase.build import bulk
from ase.io import read, Trajectory, write
from ase.constraints import FixAtoms
import os
import time
from datetime import datetime
from sklearn.linear_model import LinearRegression
from matlantis_features.features.md import ASEMDSystem, LangevinIntegrator, MDFeature, MDExtensionBase, NPTIntegrator,AndersenIntegrator,NPTBerendsenIntegrator,NVTBerendsenIntegrator,VelocityVerletIntegrator
from matlantis_features.features.md.md_extensions import DeformScheduler
from pfp_api_client.pfp.estimator import Estimator, EstimatorCalcMode
from pfp_api_client.pfp.calculators.ase_calculator import ASECalculator
from matlantis_features.utils.calculators import get_calculator, pfp_estimator_fn
from matlantis_features.utils.atoms_util import convert_atoms_to_upper
from matlantis_features.atoms import MatlantisAtoms
import pandas as pd
from pathlib import Path
from ase import units
from ase.build import add_vacuum
import re

# Matlantis / PFP
from matlantis_features.features.md import (
    MDFeature,
    ASEMDSystem,
    VelocityVerletIntegrator,
    LangevinIntegrator,
    NVTBerendsenIntegrator,
    NPTBerendsenIntegrator,
    NPTIntegrator,
)
from matlantis_features.utils.calculators import pfp_estimator_fn
from pfp_api_client.pfp.estimator import EstimatorCalcMode

# --- ユーザー設定項目 (ここを編集してください) ---

# 1. 使用するIntegratorの種類を選択
#    選択肢: "NVE", "Langevin", "NVT_Berendsen", "NPT_Berendsen", "NPT"VelocityVerletIntegrator
# LangevinIntegrator
# AndersenIntegrator
# NVTBerendsenIntegrator
# NPTBerendsenIntegrator
# NPTIntegrator
INTEGRATOR_TYPE = "NVT_Berendsen"

# 2. 初期構造のファイルパスを指定 (ASEが読み込める形式ならOK)
#    例: "POSCAR", "input.cif", "structure.xyz"
#    指定しない場合は、Siのバルク結晶で計算します。
INPUT_STRUCTURE_FILE ="pvdf_opt2.traj"  # "your_structure_file.cif" など

# 3. MDシミュレーションの基本パラメータ
N_RUN_STEPS = 5000          # 実行するステップ数
TIME_STEP_FS = 1.0         # タイムステップ (fs)
TEMPERATURE_K = 1500        # 温度 (K)
PRESSURE_PA = 101325       # 圧力 (Pa) ※NPT系でのみ使用

# 4. ログとトラジェクトリの設定
SHOW_PROGRESS = True       # 進捗バーを表示するか
SHOW_LOGGER = True         # ログを標準出力に表示するか
LOGGER_INTERVAL = 50       # ログを出力する間隔 (ステップ数)
TRAJ_FILE_NAME = "NVT_1500K1.traj"  # 出力トラジェクトリファイル名
TRAJ_FREQ = 50             # トラジェクトリを保存する間隔 (ステップ数)
vacuum=0.2
# 5. PFPモデルの計算設定
PFP_MODEL_VERSION = 'v7.0.0'
PFP_CALC_MODE = EstimatorCalcMode.CRYSTAL_U0

# --- 設定項目ここまで ---


def select_integrator(integrator_type: str):
    """
    指定された文字列に応じて、対応するIntegratorオブジェクトを返す関数。
    """
    print(f"--- Integrator: '{integrator_type}' を選択しました ---")
    
    # NPT系で使用する圧力 (ASE unitsに変換)
    pressure_au = PRESSURE_PA * units.Pascal

    if integrator_type == "NVE":
        # Microcanonical (NVE) ensemble using the Velocity Verlet algorithm
        return VelocityVerletIntegrator(timestep=TIME_STEP_FS)
        
    elif integrator_type == "Langevin":
        # Langevin dynamics for NVT ensemble
        return LangevinIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            friction=0.002  # 摩擦係数 (調整が必要な場合あり)
        )

    elif integrator_type == "NVT_Berendsen":
        # NVT ensemble with Berendsen thermostat
        return NVTBerendsenIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            taut=100.0 * units.fs  # 温度緩和時間
        )
        
    elif integrator_type == "NPT_Berendsen":
        # NPT ensemble with Berendsen thermostat and barostat
        return NPTBerendsenIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            pressure=pressure_au,
            taut=100.0 * units.fs,    # 温度緩和時間
            taup=1000.0 * units.fs    # 圧力緩和時間
        )
        
    elif integrator_type == "NPT":
        # NPT ensemble with Nosé-Hoover thermostat and Parrinello-Rahman barostat
        return NPTIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            pressure=pressure_au,
            ttime=25.0 * units.fs,    # 温度緩和時間 (Nosé-Hoover)
            pfactor=75.0 * units.fs  # 圧力緩和時間 (Parrinello-Rahman)
        )
        
    else:
        raise ValueError(f"エラー: 指定されたIntegrator '{integrator_type}' は不正です。")


def run_md_simulation():
    """
    設定に基づいてMDシミュレーションを実行するメイン関数。
    """
    # Matlantis-featuresのロガー設定
    logger = logging.getLogger("matlantis_features")
    logger.setLevel(logging.INFO)

    # 1. PFP計算器の準備
    estimator_fn = pfp_estimator_fn(model_version=PFP_MODEL_VERSION, calc_mode=PFP_CALC_MODE)
    # MOLECULE = Atoms('H2O')                 # 追加する分子
    # SPACING = 3.0                           # 分子間隔 (Å)
    # Z_OFFSET = 3.0 
    # atoms = Trajectory(INPUT_STRUCTURE_FILE)[-1]
    # positions = atoms.get_positions()
    # center_x, center_y, _ = positions.mean(axis=0)
    # max_z = np.max(positions[:, 2])
    # grid_center = np.array([center_x, center_y, max_z + Z_OFFSET])
    
    # # 3. 9分子のグリッドを作成
    # molecule_grid = Atoms()
    # MOLECULE.center()
    # offset = (3 - 1) / 2.0  # 3x3グリッドの中心化オフセット
    
    # for ix in range(3):
    #     for iy in range(3):
    #         pos = grid_center + np.array([(ix - offset) * SPACING, (iy - offset) * SPACING, 0.0])
    #         mol_copy = MOLECULE.copy()
    #         mol_copy.translate(pos)
    #         molecule_grid.extend(mol_copy)
    
    # # 4. 既存構造とグリッドを結合
    # atoms.extend(molecule_grid)
    # vacuum = 0.5
            
    # # 3. 全原子の座標を取得し、各軸の最小値と最大値を計算
    # positions = atoms.get_positions()
    # min_coords = positions.min(axis=0)
    # max_coords = positions.max(axis=0)
    
    # # 4. 新しいセルの大きさを計算
    # #    (分子の最大幅) + (両側の真空層)
    # cell_lengths = (max_coords - min_coords) + 2 * vacuum
    # new_cell = np.diag(cell_lengths)
    
    # # 5. 計算したセルをatomsオブジェクトに設定
    # atoms.set_cell(new_cell)
    # atoms.pbc=True
    # atoms.center()
    # write("pvdf_h2o.xyz",atoms)
    # # 2. 初期構造の準備
    # if INPUT_STRUCTURE_FILE:
    #     try:
    #         existing_atoms = Trajectory(INPUT_STRUCTURE_FILE)[-1]
    #         from ase import Atoms
    #         h2o=Atoms('H2O')
    #         NUM_WATER_MOLECULES = 5
    #         # 既存構造と最初の水分子とのZ方向の距離 (Å)
    #         INITIAL_SEPARATION = 3.0
    #         # 水分子同士のZ方向の距離 (Å)
    #         WATER_SEPARATION = 3.0
    #         # 
    #         NUM_COLUMNS_NX=5
    #         WATER_SEPARATION_XY=3.0
    #         water_layer = Atoms()
    #         h2o.center(about=(0,0,0))
    #         for i in range(NUM_WATER_MOLECULES):
    #             # グリッド上の位置を計算 (ix: 列, iy: 行)
    #             ix = i % NUM_COLUMNS_NX
    #             iy = i // NUM_COLUMNS_NX
            
    #             # 配置する座標を計算
    #             position = np.array([ix * WATER_SEPARATION_XY, iy * WATER_SEPARATION_XY, 0.0])
            
    #             # テンプレートをコピーして、計算した位置に移動
    #             h2o_to_add = h2o.copy()
    #             h2o_to_add.translate(position)
            
    #             # レイヤーに水分子を追加
    #             water_layer.extend(h2o_to_add)
    #             print(f"{i+1}個目の水分子を (x, y) ≈ ({position[0]:.1f}, {position[1]:.1f}) に配置しました。")
            
    #         # レイヤー全体の重心が原点に来るように移動
    #         water_layer.center(about=(0,0,0))
    #         print("作成した水分子レイヤーを X-Y 平面でセンタリングしました。")


    #         # from pfcc_extras import show_gui, view_ngl
    #         # from ase.io import Trajectory,read
    #         max_z_existing = np.max(existing_atoms.get_positions()[:, 2])
    #         print(f"既存構造のZ方向の最大座標: {max_z_existing:.2f} Å")
    #         # 4. 水分子をZ方向に追加していく
    #         # 最初の水分子を配置するZ座標を計算
    #         current_z = max_z_existing + INITIAL_SEPARATION
    #         h2o_to_add.positions[:, 2] += current_z
    #         existing_atoms.extend(h2o_to_add)
            # for i in range(NUM_WATER_MOLECULES):
            #     # 配置する水分子のコピーを作成
            #     h2o_to_add = h2o.copy()
            
            #     # 水分子をZ方向に移動させる
            #     # h2o_to_add.positions は (N, 3) のNumpy配列なので、
            #     # Z座標の列 ([:, 2]) に current_z を加算する
            #     h2o_to_add.positions[:, 2] += current_z
            
            #     # 既存のAtomsオブジェクトに水分子の原子を追加
    #         #     existing_atoms.extend(h2o_to_add)
            
    #         #     print(f"{i+1}個目の水分子を Z ≈ {current_z:.2f} Å の位置に追加しました。")
            
    #         #     # 次の水分子を配置するZ座標を更新
    #         #     current_z += WATER_SEPARATION
    #         atoms=existing_atoms.copy()
    #         # estimator = Estimator(model_version=PFP_MODEL_VERSION,calc_mode=PFP_CALC_MODE)
    #         # calculator = ASECalculator(estimator)
    #         # atoms.calc=calculator
    #         # atoms.get_stress()
    #         vacuum = 0.5
            
    #         # 3. 全原子の座標を取得し、各軸の最小値と最大値を計算
    #         positions = atoms.get_positions()
    #         min_coords = positions.min(axis=0)
    #         max_coords = positions.max(axis=0)
            
    #         # 4. 新しいセルの大きさを計算
    #         #    (分子の最大幅) + (両側の真空層)
    #         cell_lengths = (max_coords - min_coords) + 2 * vacuum
    #         new_cell = np.diag(cell_lengths)
            
    #         # 5. 計算したセルをatomsオブジェクトに設定
    #         atoms.set_cell(new_cell)
    #         atoms.pbc=True
            
    #         print(f"構造ファイル '{INPUT_STRUCTURE_FILE}' を読み込みました。原子数: {len(atoms)}")
    #     except FileNotFoundError:
    #         print(f"エラー: ファイル '{INPUT_STRUCTURE_FILE}' が見つかりません。")
    #         return
    # else:
    #     atoms = bulk("Si", cubic=True) * (2, 2, 2)
    #     print("構造ファイルが指定されなかったため、Siのバルク構造を生成しました。")
    
    # 3. MDシステムの初期化
    atoms=read("pvdf_opt.xyz")
    positions = atoms.get_positions()
    min_coords = positions.min(axis=0)
    max_coords = positions.max(axis=0)
    
    # 4. 新しいセルの大きさを計算
    #    (分子の最大幅) + (両側の真空層)
    cell_lengths = (max_coords - min_coords) + 2 * vacuum
    new_cell = np.diag(cell_lengths)
    
    # 5. 計算したセルをatomsオブジェクトに設定
    atoms.set_cell(new_cell)
    atoms.pbc=True
    system = ASEMDSystem(atoms)
    
    # 乱数シードを固定して温度を初期化（再現性のため）
    system.init_temperature(temperature=TEMPERATURE_K, stationary=True, rng=np.random.RandomState(seed=12345))
    print(f"システムを {TEMPERATURE_K} K に初期化しました。")

    # 4. Integratorの選択と準備
    try:
        integrator = select_integrator(INTEGRATOR_TYPE)
    except ValueError as e:
        print(e)
        return

    # 5. MDFeatureの設定
    md = MDFeature(
        integrator=integrator,
        n_run=N_RUN_STEPS,
        show_progress_bar=SHOW_PROGRESS,
        show_logger=SHOW_LOGGER,
        logger_interval=LOGGER_INTERVAL,
        traj_file_name=TRAJ_FILE_NAME,
        traj_freq=TRAJ_FREQ,
        estimator_fn=estimator_fn,
    )

    # 6. MDシミュレーションの実行
    print(f"\n--- MDシミュレーションを開始します ({N_RUN_STEPS} ステップ) ---")
    md_results = md(system)

    print("\n--- MDシミュレーションが正常に完了しました ---")
    print(f"最終的なトラジェクトリは '{TRAJ_FILE_NAME}' に保存されました。")
    print(f"最終ステップ: {system.current_total_step}, 最終時間: {system.current_time:.2f} fs")


if __name__ == "__main__":
    run_md_simulation()
# Out:
# システムを 1500 K に初期化しました。
# --- Integrator: 'NVT_Berendsen' を選択しました ---
#
# --- MDシミュレーションを開始します (5000 ステップ) ---
#   0%|          | 0/5000 [00:00<?, ?it/s]
# The MD trajectory will be saved at /home/jovyan/Kaori/MD/LiB_2/structure/NVT_1500K1.traj.
# Note: The max disk size of /home/jovyan is about 98G.
# steps:     0  energy：-4.45 eV/atom  total energy: -4.26 eV/atom  temperature: 1506.85 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:    50  energy：-4.33 eV/atom  total energy: -4.14 eV/atom  temperature: 1438.04 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   100  energy：-4.34 eV/atom  total energy: -4.13 eV/atom  temperature: 1563.99 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   150  energy：-4.32 eV/atom  total energy: -4.13 eV/atom  temperature: 1461.88 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   200  energy：-4.34 eV/atom  total energy: -4.14 eV/atom  temperature: 1522.14 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   250  energy：-4.33 eV/atom  total energy: -4.15 eV/atom  temperature: 1462.17 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   300  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1472.71 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   350  energy：-4.33 eV/atom  total energy: -4.14 eV/atom  temperature: 1472.65 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   400  energy：-4.34 eV/atom  total energy: -4.14 eV/atom  temperature: 1526.52 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   450  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1492.53 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   500  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1479.65 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   550  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1484.78 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   600  energy：-4.33 eV/atom  total energy: -4.14 eV/atom  temperature: 1487.81 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   650  energy：-4.33 eV/atom  total energy: -4.14 eV/atom  temperature: 1513.63 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   700  energy：-4.33 eV/atom  total energy: -4.14 eV/atom  temperature: 1474.80 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   750  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1482.43 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   800  energy：-4.34 eV/atom  total energy: -4.14 eV/atom  temperature: 1533.95 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   850  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1488.27 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   900  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1462.72 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   950  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1473.11 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1000  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1469.39 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1050  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1517.19 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1100  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1521.06 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1150  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1503.57 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1200  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1485.41 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1250  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1473.98 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1300  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1495.53 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1350  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1512.32 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1400  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1475.33 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1450  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1493.78 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1500  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1489.30 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1550  energy：-4.33 eV/atom  total energy: -4.14 eV/atom  temperature: 1479.81 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1600  energy：-4.34 eV/atom  total energy: -4.14 eV/atom  temperature: 1514.47 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1650  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1480.37 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1700  energy：-4.33 eV/atom  total energy: -4.15 eV/atom  temperature: 1454.40 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1750  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1482.52 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1800  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1527.41 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1850  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1527.15 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1900  energy：-4.35 eV/atom  total energy: -4.16 eV/atom  temperature: 1481.19 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1950  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1503.29 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2000  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1531.98 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2050  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1464.39 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2100  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1537.72 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2150  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1528.10 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2200  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1469.00 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2250  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1517.70 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2300  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1481.99 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2350  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1514.32 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2400  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1522.19 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2450  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1468.74 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2500  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1531.60 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2550  energy：-4.35 eV/atom  total energy: -4.16 eV/atom  temperature: 1481.63 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2600  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1487.46 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2650  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1446.81 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2700  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1523.33 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2750  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1499.92 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2800  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1508.71 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2850  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1515.00 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2900  energy：-4.34 eV/atom  total energy: -4.14 eV/atom  temperature: 1497.54 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2950  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1505.35 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3000  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1478.80 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3050  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1539.00 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3100  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1509.39 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3150  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1455.68 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3200  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1549.58 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3250  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1465.19 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3300  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1469.12 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3350  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1530.16 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3400  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1534.13 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3450  energy：-4.33 eV/atom  total energy: -4.14 eV/atom  temperature: 1453.96 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3500  energy：-4.33 eV/atom  total energy: -4.14 eV/atom  temperature: 1454.50 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3550  energy：-4.33 eV/atom  total energy: -4.14 eV/atom  temperature: 1484.55 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3600  energy：-4.34 eV/atom  total energy: -4.14 eV/atom  temperature: 1507.16 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3650  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1463.19 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3700  energy：-4.34 eV/atom  total energy: -4.14 eV/atom  temperature: 1494.78 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3750  energy：-4.34 eV/atom  total energy: -4.14 eV/atom  temperature: 1506.67 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3800  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1439.28 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3850  energy：-4.34 eV/atom  total energy: -4.14 eV/atom  temperature: 1511.77 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3900  energy：-4.34 eV/atom  total energy: -4.14 eV/atom  temperature: 1534.10 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3950  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1535.80 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4000  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1477.48 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4050  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1508.68 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4100  energy：-4.34 eV/atom  total energy: -4.14 eV/atom  temperature: 1524.21 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4150  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1513.10 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4200  energy：-4.34 eV/atom  total energy: -4.14 eV/atom  temperature: 1520.02 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4250  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1526.79 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4300  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1518.53 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4350  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1489.22 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4400  energy：-4.35 eV/atom  total energy: -4.16 eV/atom  temperature: 1472.02 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4450  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1451.41 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4500  energy：-4.35 eV/atom  total energy: -4.16 eV/atom  temperature: 1504.03 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4550  energy：-4.35 eV/atom  total energy: -4.16 eV/atom  temperature: 1505.71 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4600  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1500.57 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4650  energy：-4.35 eV/atom  total energy: -4.16 eV/atom  temperature: 1505.73 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4700  energy：-4.35 eV/atom  total energy: -4.16 eV/atom  temperature: 1474.81 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4750  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1516.43 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4800  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1487.47 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4850  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1488.29 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4900  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1498.60 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4950  energy：-4.34 eV/atom  total energy: -4.15 eV/atom  temperature: 1500.32 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  5000  energy：-4.35 eV/atom  total energy: -4.15 eV/atom  temperature: 1515.57 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# --- MDシミュレーションが正常に完了しました ---
# 最終的なトラジェクトリは 'NVT_1500K1.traj' に保存されました。
# 最終ステップ: 5000, 最終時間: 5000.00 fs

# %%
## -*- coding: utf-8 -*-
import logging
import numpy as np
from ase import units
from ase.build import bulk
from ase.io import read, Trajectory, write
from ase.constraints import FixAtoms
import os
import time
from datetime import datetime
from sklearn.linear_model import LinearRegression
from matlantis_features.features.md import ASEMDSystem, LangevinIntegrator, MDFeature, MDExtensionBase, NPTIntegrator,AndersenIntegrator,NPTBerendsenIntegrator,NVTBerendsenIntegrator,VelocityVerletIntegrator
from matlantis_features.features.md.md_extensions import DeformScheduler
from pfp_api_client.pfp.estimator import Estimator, EstimatorCalcMode
from pfp_api_client.pfp.calculators.ase_calculator import ASECalculator
from matlantis_features.utils.calculators import get_calculator, pfp_estimator_fn
from matlantis_features.utils.atoms_util import convert_atoms_to_upper
from matlantis_features.atoms import MatlantisAtoms
import pandas as pd
from pathlib import Path
from ase import units
from ase.build import add_vacuum
import re

# Matlantis / PFP
from matlantis_features.features.md import (
    MDFeature,
    ASEMDSystem,
    VelocityVerletIntegrator,
    LangevinIntegrator,
    NVTBerendsenIntegrator,
    NPTBerendsenIntegrator,
    NPTIntegrator,
)
from matlantis_features.utils.calculators import pfp_estimator_fn
from pfp_api_client.pfp.estimator import EstimatorCalcMode

# --- ユーザー設定項目 (ここを編集してください) ---

# 1. 使用するIntegratorの種類を選択
#    選択肢: "NVE", "Langevin", "NVT_Berendsen", "NPT_Berendsen", "NPT"VelocityVerletIntegrator
# LangevinIntegrator
# AndersenIntegrator
# NVTBerendsenIntegrator
# NPTBerendsenIntegrator
# NPTIntegrator
INTEGRATOR_TYPE = "NVT_Berendsen"

# 2. 初期構造のファイルパスを指定 (ASEが読み込める形式ならOK)
#    例: "POSCAR", "input.cif", "structure.xyz"
#    指定しない場合は、Siのバルク結晶で計算します。
# INPUT_STRUCTURE_FILE ="pvdf_opt2.traj"  # "your_structure_file.cif" など

# 3. MDシミュレーションの基本パラメータ
N_RUN_STEPS = 100000          # 実行するステップ数
TIME_STEP_FS = 1.0         # タイムステップ (fs)
TEMPERATURE_K = 600        # 温度 (K)
PRESSURE_PA = 101325       # 圧力 (Pa) ※NPT系でのみ使用
# --- 緩和計算の設定 ---
RELAX_TEMP = 300.0      # 緩和計算の温度 (K)
N_RELAX_STEPS = 5000    # 緩和計算のステップ数
RELAX_TRAJ_FILE_NAME = "relax_pvdf_water_random_600K.traj"
# 4. ログとトラジェクトリの設定
SHOW_PROGRESS = True       # 進捗バーを表示するか
SHOW_LOGGER = True         # ログを標準出力に表示するか
LOGGER_INTERVAL = 50       # ログを出力する間隔 (ステップ数)
TRAJ_FILE_NAME = "pvdf_water_random_600K.traj"  # 出力トラジェクトリファイル名
TRAJ_FREQ = 50             # トラジェクトリを保存する間隔 (ステップ数)
vacuum=0.2
# 5. PFPモデルの計算設定
PFP_MODEL_VERSION = 'v7.0.0'
PFP_CALC_MODE = EstimatorCalcMode.CRYSTAL_U0

# --- 設定項目ここまで ---


def select_integrator(integrator_type: str):
    """
    指定された文字列に応じて、対応するIntegratorオブジェクトを返す関数。
    """
    print(f"--- Integrator: '{integrator_type}' を選択しました ---")
    
    # NPT系で使用する圧力 (ASE unitsに変換)
    pressure_au = PRESSURE_PA * units.Pascal

    if integrator_type == "NVE":
        # Microcanonical (NVE) ensemble using the Velocity Verlet algorithm
        return VelocityVerletIntegrator(timestep=TIME_STEP_FS)
        
    elif integrator_type == "Langevin":
        # Langevin dynamics for NVT ensemble
        return LangevinIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            friction=0.002  # 摩擦係数 (調整が必要な場合あり)
        )

    elif integrator_type == "NVT_Berendsen":
        # NVT ensemble with Berendsen thermostat
        return NVTBerendsenIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            taut=100.0 * units.fs  # 温度緩和時間
        )
        
    elif integrator_type == "NPT_Berendsen":
        # NPT ensemble with Berendsen thermostat and barostat
        return NPTBerendsenIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            pressure=pressure_au,
            taut=100.0 * units.fs,    # 温度緩和時間
            taup=1000.0 * units.fs    # 圧力緩和時間
        )
        
    elif integrator_type == "NPT":
        # NPT ensemble with Nosé-Hoover thermostat and Parrinello-Rahman barostat
        return NPTIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            pressure=pressure_au,
            ttime=25.0 * units.fs,    # 温度緩和時間 (Nosé-Hoover)
            pfactor=75.0 * units.fs  # 圧力緩和時間 (Parrinello-Rahman)
        )
        
    else:
        raise ValueError(f"エラー: 指定されたIntegrator '{integrator_type}' は不正です。")


def run_md_simulation():
    """
    設定に基づいてMDシミュレーションを実行するメイン関数。
    """
    # Matlantis-featuresのロガー設定
    logger = logging.getLogger("matlantis_features")
    logger.setLevel(logging.INFO)

    # 1. PFP計算器の準備
    estimator_fn = pfp_estimator_fn(model_version=PFP_MODEL_VERSION, calc_mode=PFP_CALC_MODE)
    
    # 3. MDシステムの初期化
    atoms=read("pvdf_water_random.xyz")
    positions = atoms.get_positions()
    min_coords = positions.min(axis=0)
    max_coords = positions.max(axis=0)
    
    # 4. 新しいセルの大きさを計算
    #    (分子の最大幅) + (両側の真空層)
    cell_lengths = (max_coords - min_coords) + 2 * vacuum
    new_cell = np.diag(cell_lengths)
    
    # 5. 計算したセルをatomsオブジェクトに設定
    atoms.set_cell(new_cell)
    atoms.pbc=True
    system = ASEMDSystem(atoms)
    
    # 乱数シードを固定して温度を初期化（再現性のため）
    system.init_temperature(temperature=TEMPERATURE_K, stationary=True, rng=np.random.RandomState(seed=12345))
    print(f"システムを {TEMPERATURE_K} K に初期化しました。")
    integrator_relax=NVTBerendsenIntegrator(
            timestep=TIME_STEP_FS,
            temperature=300,
            taut=100.0 * units.fs  # 温度緩和時間
        )
    # 4. Integratorの選択と準備
    try:
        integrator = select_integrator(INTEGRATOR_TYPE)
    except ValueError as e:
        print(e)
        return
    # 5. MDFeatureの設定
    md_relax = MDFeature(
        integrator=integrator_relax,
        n_run=1000,
        show_progress_bar=SHOW_PROGRESS,
        show_logger=SHOW_LOGGER,
        logger_interval=LOGGER_INTERVAL,
        traj_file_name=RELAX_TRAJ_FILE_NAME,
        traj_freq=TRAJ_FREQ,
        estimator_fn=estimator_fn,
    )

    # 6. MDシミュレーションの実行
    print(f"\n--- MDシミュレーションを開始します ({N_RUN_STEPS} ステップ) ---")
    md_results = md_relax(system)
    # 5. MDFeatureの設定
    md = MDFeature(
        integrator=integrator,
        n_run=N_RUN_STEPS,
        show_progress_bar=SHOW_PROGRESS,
        show_logger=SHOW_LOGGER,
        logger_interval=LOGGER_INTERVAL,
        traj_file_name=TRAJ_FILE_NAME,
        traj_freq=TRAJ_FREQ,
        estimator_fn=estimator_fn,
    )

    # 6. MDシミュレーションの実行
    print(f"\n--- MDシミュレーションを開始します ({N_RUN_STEPS} ステップ) ---")
    md_results = md(system)

    print("\n--- MDシミュレーションが正常に完了しました ---")
    print(f"最終的なトラジェクトリは '{TRAJ_FILE_NAME}' に保存されました。")
    print(f"最終ステップ: {system.current_total_step}, 最終時間: {system.current_time:.2f} fs")


if __name__ == "__main__":
    run_md_simulation()
# Out:
# /home/jovyan/.py311/lib/python3.11/site-packages/pfp_api_client/__init__.py:42: UserWarning: New version of pfp-api-client is available. Please consider upgrading by `pip install -U pfp-api-client`.
#   warnings.warn(
# システムを 600 K に初期化しました。
# --- Integrator: 'NVT_Berendsen' を選択しました ---
#
# --- MDシミュレーションを開始します (100000 ステップ) ---
#   0%|          | 0/1000 [00:00<?, ?it/s]
# The MD trajectory will be saved at /home/jovyan/Kaori/MD/LiB_2/structure/relax_pvdf_water_random_600K.traj.
# Note: The max disk size of /home/jovyan is about 98G.
# steps:     0  energy： 4.58 eV/atom  total energy:  4.65 eV/atom  temperature: 596.51 K  volume: 36313 Ang^3  density: 1.521 g/cm^3
# steps:    50  energy：-0.88 eV/atom  total energy: 93829.55 eV/atom  temperature: 725904927.32 K  volume: 36313 Ang^3  density: 1.521 g/cm^3
# steps:   100  energy：-1.53 eV/atom  total energy: 532.32 eV/atom  temperature: 4130086.99 K  volume: 36313 Ang^3  density: 1.521 g/cm^3
# steps:   150  energy：-2.14 eV/atom  total energy: 40.26 eV/atom  temperature: 328060.70 K  volume: 36313 Ang^3  density: 1.521 g/cm^3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 208
#     204     print(f"最終ステップ: {system.current_total_step}, 最終時間: {system.current_time:.2f} fs")
#     207 if __name__ == "__main__":
# --> 208     run_md_simulation()
#
# Cell In[1], line 185, in run_md_simulation()
#     183 # 6. MDシミュレーションの実行
#     184 print(f"\n--- MDシミュレーションを開始します ({N_RUN_STEPS} ステップ) ---")
# --> 185 md_results = md_relax(system)
#     186 # 5. MDFeatureの設定
#     187 md = MDFeature(
#     188     integrator=integrator,
#     189     n_run=N_RUN_STEPS,
#    (...)
#     195     estimator_fn=estimator_fn,
#     196 )
#
# File ~/.py311/lib/python3.11/site-packages/matlantis_features/features/base.py:131, in FeatureBaseCaller.call_decorate.<locals>.decorated(self, *args, **kwargs)
#     129 args_list = [copy_to_child_conversion(arg) for arg in args]
#     130 kwargs_new = {k: copy_to_child_conversion(v) for k, v in kwargs.items()}
# --> 131 res = derived_call(self, *args_list, **kwargs_new)
#     132 return res
#
# File ~/.py311/lib/python3.11/site-packages/matlantis_features/features/md/md.py:353, in MDFeature.__call__(self, system, extensions)
#     345     trajw = ASETrajWriter(
#     346         file_name=traj_fname,
#     347         write_mode=self.traj_write_mode,
#     348         props=self.traj_props,
#     349         save_init_frame=self.traj_init_frame,
#     350     )
#     351     sim.append_extension(trajw, self.traj_freq)
# --> 353 sim.run(n_run_steps=self.n_run)
#     355 if trajw is not None:
#     356     trajw.close()
#
# File ~/.py311/lib/python3.11/site-packages/matlantis_features/features/md/ase_simulation.py:192, in ASESimulation.run(self, n_run_steps)
#     187 if isinstance(self.integrator, NPTIntegrator):
#     188     # The ase.md.npt.NPT does not call the observers at step==0.
#     189     # To keep consistency with the other dynamics obj, we add the following line.
#     190     dyn.call_observers()
# --> 192 dyn.run(steps=n_run_steps)
#
# File ~/.py311/lib/python3.11/site-packages/ase/md/md.py:171, in MolecularDynamics.run(self, steps)
#     158 def run(self, steps=50):
#     159     """Run molecular dynamics algorithm.
#     160
#     161     Parameters
#    (...)
#     169         True if the maximum number of steps are reached.
#     170     """
# --> 171     return Dynamics.run(self, steps=steps)
#
# File ~/.py311/lib/python3.11/site-packages/ase/optimize/optimize.py:286, in Dynamics.run(self, steps)
#     268 def run(self, steps=DEFAULT_MAX_STEPS):
#     269     """Run dynamics algorithm.
#     270
#     271     This method will return when the forces on all individual
#    (...)
#     283         True if the forces on atoms are converged.
#     284     """
# --> 286     for converged in Dynamics.irun(self, steps=steps):
#     287         pass
#     288     return converged
#
# File ~/.py311/lib/python3.11/site-packages/ase/optimize/optimize.py:257, in Dynamics.irun(self, steps)
#     254 # run the algorithm until converged or max_steps reached
#     255 while not is_converged and self.nsteps < self.max_steps:
#     256     # compute the next step
# --> 257     self.step()
#     258     self.nsteps += 1
#     260     # log the step
#
# File ~/.py311/lib/python3.11/site-packages/ase/md/nvtberendsen.py:142, in NVTBerendsen.step(self, forces)
#     135 # We need to store the momenta on the atoms before calculating
#     136 # the forces, as in a parallel Asap calculation atoms may
#     137 # migrate during force calculations, and the momenta need to
#     138 # migrate along with the atoms.  For the same reason, we
#     139 # cannot use self.masses in the line above.
#     141 self.atoms.set_momenta(p)
# --> 142 forces = self.atoms.get_forces(md=True)
#     143 atoms.set_momenta(self.atoms.get_momenta() + 0.5 * self.dt * forces)
#     145 return forces
#
# File ~/.py311/lib/python3.11/site-packages/ase/atoms.py:829, in Atoms.get_forces(self, apply_constraint, md)
#     827 if self._calc is None:
#     828     raise RuntimeError('Atoms object has no calculator.')
# --> 829 forces = self._calc.get_forces(self)
#     831 if apply_constraint:
#     832     # We need a special md flag here because for MD we want
#     833     # to skip real constraints but include special "constraints"
#     834     # Like Hookean.
#     835     for constraint in self.constraints:
#
# File ~/.py311/lib/python3.11/site-packages/ase/calculators/abc.py:32, in GetPropertiesMixin.get_forces(self, atoms)
#      31 def get_forces(self, atoms=None):
# ---> 32     return self.get_property('forces', atoms)
#
# File ~/.py311/lib/python3.11/site-packages/ase/calculators/calculator.py:515, in BaseCalculator.get_property(self, name, atoms, allow_calculation)
#     512     if self.use_cache:
#     513         self.atoms = atoms.copy()
# --> 515     self.calculate(atoms, [name], system_changes)
#     517 if name not in self.results:
#     518     # For some reason the calculator was not able to do what we want,
#     519     # and that is OK.
#     520     raise PropertyNotImplementedError(
#     521         '{} not present in this ' 'calculation'.format(name)
#     522     )
#
# File ~/.py311/lib/python3.11/site-packages/pfp_api_client/pfp/calculators/ase_calculator.py:131, in ASECalculator.calculate(self, atoms, properties, system_changes)
#     128 try:
#     129     # check that we were not interrupted by SIGINT
#     130     InterruptWatcher.assert_not_interrupted()
# --> 131     return self._calculate(atoms, properties, system_changes)
#     132 finally:
#     133     self.concurrency_checker.release()
#
# File ~/.py311/lib/python3.11/site-packages/pfp_api_client/pfp/calculators/ase_calculator.py:183, in ASECalculator._calculate(self, atoms, properties, system_changes)
#     180 coordinates = self.atoms.get_positions()
#     181 properties_estimator = self.reverse_convert_properties(_properties)
# --> 183 self.results = self.estimator.estimate(
#     184     EstimatorSystem(
#     185         properties=properties_estimator,
#     186         coordinates=coordinates,
#     187         cell=cell_array,
#     188         atomic_numbers=atomic_numbers,
#     189         pbc=pbc,
#     190     )
#     191 )
#     193 # NOTE (himkt): to make compatible with ``SinglePointCalculator``.
#     194 for key, value in self.results.items():
#
# File ~/.py311/lib/python3.11/site-packages/pfp_api_client/pfp/estimator.py:926, in Estimator.estimate(self, args)
#     917     application_context = (
#     918         self.application_context
#     919         if self.application_context is not None
#    (...)
#     923         )
#     924     )
#     925     metadata.append((METADATA_APPLICATION_CONTEXT, application_context.lower()))
# --> 926     response = self.stub.Estimate(request, metadata=metadata)
#     927 else:
#     928     raise ValueError(
#     929         f"{_calc_mode} is not a valid calculation mode. "
#     930         f"Valid calculation modes are {', '.join(mode.name for mode in EstimatorCalcMode)}."
#     931     )
#
# File ~/.py311/lib/python3.11/site-packages/grpc/_interceptor.py:277, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     268 def __call__(
#     269     self,
#     270     request: Any,
#    (...)
#     275     compression: Optional[grpc.Compression] = None,
#     276 ) -> Any:
# --> 277     response, ignored_call = self._with_call(
#     278         request,
#     279         timeout=timeout,
#     280         metadata=metadata,
#     281         credentials=credentials,
#     282         wait_for_ready=wait_for_ready,
#     283         compression=compression,
#     284     )
#     285     return response
#
# File ~/.py311/lib/python3.11/site-packages/grpc/_interceptor.py:329, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     326     except Exception as exception:  # pylint:disable=broad-except
#     327         return _FailureOutcome(exception, sys.exc_info()[2])
# --> 329 call = self._interceptor.intercept_unary_unary(
#     330     continuation, client_call_details, request
#     331 )
#     332 return call.result(), call
#
# File ~/.py311/lib/python3.11/site-packages/pfp_api_client/utils/error_handler_client_interceptor.py:24, in ErrorHandlerClientInterceptor.intercept_unary_unary(self, continuation, client_call_details, request)
#      17 def intercept_unary_unary(
#      18     self,
#      19     continuation: Callable[[grpc.ClientCallDetails, Message], Any],
#      20     client_call_details: grpc.ClientCallDetails,
#      21     request: Message,
#      22 ) -> Union[grpc.Call, grpc.Future]:
#      23     return self._handle_response(
# ---> 24         client_call_details, continuation(client_call_details, request)
#      25     )
#
# File ~/.py311/lib/python3.11/site-packages/grpc/_interceptor.py:315, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     306 (
#     307     new_method,
#     308     new_timeout,
#    (...)
#     312     new_compression,
#     313 ) = _unwrap_client_call_details(new_details, client_call_details)
#     314 try:
# --> 315     response, call = self._thunk(new_method).with_call(
#     316         request,
#     317         timeout=new_timeout,
#     318         metadata=new_metadata,
#     319         credentials=new_credentials,
#     320         wait_for_ready=new_wait_for_ready,
#     321         compression=new_compression,
#     322     )
#     323     return _UnaryOutcome(response, call)
#     324 except grpc.RpcError as rpc_error:
#
# File ~/.py311/lib/python3.11/site-packages/grpc/_interceptor.py:343, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     334 def with_call(
#     335     self,
#     336     request: Any,
#    (...)
#     341     compression: Optional[grpc.Compression] = None,
#     342 ) -> Tuple[Any, grpc.Call]:
# --> 343     return self._with_call(
#     344         request,
#     345         timeout=timeout,
#     346         metadata=metadata,
#     347         credentials=credentials,
#     348         wait_for_ready=wait_for_ready,
#     349         compression=compression,
#     350     )
#
# File ~/.py311/lib/python3.11/site-packages/grpc/_interceptor.py:329, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     326     except Exception as exception:  # pylint:disable=broad-except
#     327         return _FailureOutcome(exception, sys.exc_info()[2])
# --> 329 call = self._interceptor.intercept_unary_unary(
#     330     continuation, client_call_details, request
#     331 )
#     332 return call.result(), call
#
# File ~/.py311/lib/python3.11/site-packages/pfp_api_client/utils/retry_client_interceptor.py:53, in RetryClientInterceptor.intercept_unary_unary(self, continuation, client_call_details, request)
#      50 def f() -> Union[grpc.Call, grpc.Future]:
#      51     return continuation(client_call_details, request)
# ---> 53 return self._retry(client_call_details, f)
#
# File ~/.py311/lib/python3.11/site-packages/pfp_api_client/utils/retry_client_interceptor.py:64, in RetryClientInterceptor._retry(self, client_call_details, f)
#      62 errors: Dict[StatusCode, int] = defaultdict(int)
#      63 while True:
# ---> 64     response = f()
#      65     code = response.code()
#      66     rate_limit_exceeded = False
#
# File ~/.py311/lib/python3.11/site-packages/pfp_api_client/utils/retry_client_interceptor.py:51, in RetryClientInterceptor.intercept_unary_unary.<locals>.f()
#      50 def f() -> Union[grpc.Call, grpc.Future]:
# ---> 51     return continuation(client_call_details, request)
#
# File ~/.py311/lib/python3.11/site-packages/grpc/_interceptor.py:315, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     306 (
#     307     new_method,
#     308     new_timeout,
#    (...)
#     312     new_compression,
#     313 ) = _unwrap_client_call_details(new_details, client_call_details)
#     314 try:
# --> 315     response, call = self._thunk(new_method).with_call(
#     316         request,
#     317         timeout=new_timeout,
#     318         metadata=new_metadata,
#     319         credentials=new_credentials,
#     320         wait_for_ready=new_wait_for_ready,
#     321         compression=new_compression,
#     322     )
#     323     return _UnaryOutcome(response, call)
#     324 except grpc.RpcError as rpc_error:
#
# File ~/.py311/lib/python3.11/site-packages/grpc/_channel.py:1195, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1183 def with_call(
#    1184     self,
#    1185     request: Any,
#    (...)
#    1190     compression: Optional[grpc.Compression] = None,
#    1191 ) -> Tuple[Any, grpc.Call]:
#    1192     (
#    1193         state,
#    1194         call,
# -> 1195     ) = self._blocking(
#    1196         request, timeout, metadata, credentials, wait_for_ready, compression
#    1197     )
#    1198     return _end_unary_response_blocking(state, call, True, None)
#
# File ~/.py311/lib/python3.11/site-packages/grpc/_channel.py:1162, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1145 state.target = _common.decode(self._target)
#    1146 call = self._channel.segregated_call(
#    1147     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1148     self._method,
#    (...)
#    1160     self._registered_call_handle,
#    1161 )
# -> 1162 event = call.next_event()
#    1163 _handle_event(event, state, self._response_deserializer)
#    1164 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:388, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:211, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:205, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:78, in grpc._cython.cygrpc._latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:62, in grpc._cython.cygrpc._internal_latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:58, in grpc._cython.cygrpc._interpret_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/tag.pyx.pxi:71, in grpc._cython.cygrpc._BatchOperationTag.event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/operation.pyx.pxi:138, in grpc._cython.cygrpc.ReceiveInitialMetadataOperation.un_c()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/metadata.pyx.pxi:69, in grpc._cython.cygrpc._metadata()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/metadata.pyx.pxi:70, in genexpr()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/metadata.pyx.pxi:64, in grpc._cython.cygrpc._metadatum()
#
# File <string>:1, in <lambda>(_cls, key, value)
#
# File ~/.py311/lib/python3.11/site-packages/pfp_api_client/pfp/utils/interrupt_watcher.py:18, in InterruptWatcher.set_interrupt_flag(signum, frame)
#      15 InterruptWatcher.interrupted_evt.set()
#      16 # perform the default action, i.e., trigger a KeyboardInterrupt
#      17 # exception in the main thread
# ---> 18 signal.default_int_handler(signum, frame)
#
# KeyboardInterrupt:

# %%
## -*- coding: utf-8 -*-
import logging
import numpy as np
from ase import units
from ase.build import bulk
from ase.io import read, Trajectory, write
from ase.constraints import FixAtoms
import os
import time
from datetime import datetime
from sklearn.linear_model import LinearRegression
from matlantis_features.features.md import ASEMDSystem, LangevinIntegrator, MDFeature, MDExtensionBase, NPTIntegrator,AndersenIntegrator,NPTBerendsenIntegrator,NVTBerendsenIntegrator,VelocityVerletIntegrator
from matlantis_features.features.md.md_extensions import DeformScheduler
from pfp_api_client.pfp.estimator import Estimator, EstimatorCalcMode
from pfp_api_client.pfp.calculators.ase_calculator import ASECalculator
from matlantis_features.utils.calculators import get_calculator, pfp_estimator_fn
from matlantis_features.utils.atoms_util import convert_atoms_to_upper
from matlantis_features.atoms import MatlantisAtoms
import pandas as pd
from pathlib import Path
from ase import units
from ase.build import add_vacuum
import re

# Matlantis / PFP
from matlantis_features.features.md import (
    MDFeature,
    ASEMDSystem,
    VelocityVerletIntegrator,
    LangevinIntegrator,
    NVTBerendsenIntegrator,
    NPTBerendsenIntegrator,
    NPTIntegrator,
)
from matlantis_features.utils.calculators import pfp_estimator_fn
from pfp_api_client.pfp.estimator import EstimatorCalcMode

# --- ユーザー設定項目 (ここを編集してください) ---

# 1. 使用するIntegratorの種類を選択
#    選択肢: "NVE", "Langevin", "NVT_Berendsen", "NPT_Berendsen", "NPT"VelocityVerletIntegrator
# LangevinIntegrator
# AndersenIntegrator
# NVTBerendsenIntegrator
# NPTBerendsenIntegrator
# NPTIntegrator
INTEGRATOR_TYPE = "NVT_Berendsen"

# 2. 初期構造のファイルパスを指定 (ASEが読み込める形式ならOK)
#    例: "POSCAR", "input.cif", "structure.xyz"
#    指定しない場合は、Siのバルク結晶で計算します。
# INPUT_STRUCTURE_FILE ="pvdf_opt2.traj"  # "your_structure_file.cif" など

# 3. MDシミュレーションの基本パラメータ
N_RUN_STEPS = 100000          # 実行するステップ数
TIME_STEP_FS = 1.0         # タイムステップ (fs)
TEMPERATURE_K = 600        # 温度 (K)
PRESSURE_PA = 101325       # 圧力 (Pa) ※NPT系でのみ使用
# --- 緩和計算の設定 ---
RELAX_TEMP = 300.0      # 緩和計算の温度 (K)
N_RELAX_STEPS = 5000    # 緩和計算のステップ数
RELAX_TRAJ_FILE_NAME = "relax_pvdf_water_random_600K.traj"
# 4. ログとトラジェクトリの設定
SHOW_PROGRESS = True       # 進捗バーを表示するか
SHOW_LOGGER = True         # ログを標準出力に表示するか
LOGGER_INTERVAL = 50       # ログを出力する間隔 (ステップ数)
TRAJ_FILE_NAME = "pvdf_water_random_600K.traj"  # 出力トラジェクトリファイル名
TRAJ_FREQ = 50             # トラジェクトリを保存する間隔 (ステップ数)
vacuum=0.2
# 5. PFPモデルの計算設定
PFP_MODEL_VERSION = 'v7.0.0'
PFP_CALC_MODE = EstimatorCalcMode.CRYSTAL_U0

# --- 設定項目ここまで ---


def select_integrator(integrator_type: str):
    """
    指定された文字列に応じて、対応するIntegratorオブジェクトを返す関数。
    """
    print(f"--- Integrator: '{integrator_type}' を選択しました ---")
    
    # NPT系で使用する圧力 (ASE unitsに変換)
    pressure_au = PRESSURE_PA * units.Pascal

    if integrator_type == "NVE":
        # Microcanonical (NVE) ensemble using the Velocity Verlet algorithm
        return VelocityVerletIntegrator(timestep=TIME_STEP_FS)
        
    elif integrator_type == "Langevin":
        # Langevin dynamics for NVT ensemble
        return LangevinIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            friction=0.002  # 摩擦係数 (調整が必要な場合あり)
        )

    elif integrator_type == "NVT_Berendsen":
        # NVT ensemble with Berendsen thermostat
        return NVTBerendsenIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            taut=100.0 * units.fs  # 温度緩和時間
        )
        
    elif integrator_type == "NPT_Berendsen":
        # NPT ensemble with Berendsen thermostat and barostat
        return NPTBerendsenIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            pressure=pressure_au,
            taut=100.0 * units.fs,    # 温度緩和時間
            taup=1000.0 * units.fs    # 圧力緩和時間
        )
        
    elif integrator_type == "NPT":
        # NPT ensemble with Nosé-Hoover thermostat and Parrinello-Rahman barostat
        return NPTIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            pressure=pressure_au,
            ttime=25.0 * units.fs,    # 温度緩和時間 (Nosé-Hoover)
            pfactor=75.0 * units.fs  # 圧力緩和時間 (Parrinello-Rahman)
        )
        
    else:
        raise ValueError(f"エラー: 指定されたIntegrator '{integrator_type}' は不正です。")


def run_md_simulation():
    """
    設定に基づいてMDシミュレーションを実行するメイン関数。
    """
    # Matlantis-featuresのロガー設定
    logger = logging.getLogger("matlantis_features")
    logger.setLevel(logging.INFO)

    # 1. PFP計算器の準備
    estimator_fn = pfp_estimator_fn(model_version=PFP_MODEL_VERSION, calc_mode=PFP_CALC_MODE)
    
    # 3. MDシステムの初期化
    atoms=Trajectory("pvdf_water_random_opt.traj")[-1]
    positions = atoms.get_positions()
    min_coords = positions.min(axis=0)
    max_coords = positions.max(axis=0)
    
    # 4. 新しいセルの大きさを計算
    #    (分子の最大幅) + (両側の真空層)
    cell_lengths = (max_coords - min_coords) + 2 * vacuum
    new_cell = np.diag(cell_lengths)
    
    # 5. 計算したセルをatomsオブジェクトに設定
    atoms.set_cell(new_cell)
    atoms.pbc=True
    system = ASEMDSystem(atoms)
    
    # 乱数シードを固定して温度を初期化（再現性のため）
    system.init_temperature(temperature=TEMPERATURE_K, stationary=True, rng=np.random.RandomState(seed=12345))
    print(f"システムを {TEMPERATURE_K} K に初期化しました。")
    integrator_relax=NVTBerendsenIntegrator(
            timestep=TIME_STEP_FS,
            temperature=300,
            taut=100.0 * units.fs  # 温度緩和時間
        )
    # 4. Integratorの選択と準備
    try:
        integrator = select_integrator(INTEGRATOR_TYPE)
    except ValueError as e:
        print(e)
        return
    # 5. MDFeatureの設定
    md_relax = MDFeature(
        integrator=integrator_relax,
        n_run=1000,
        show_progress_bar=SHOW_PROGRESS,
        show_logger=SHOW_LOGGER,
        logger_interval=LOGGER_INTERVAL,
        traj_file_name=RELAX_TRAJ_FILE_NAME,
        traj_freq=TRAJ_FREQ,
        estimator_fn=estimator_fn,
    )

    # 6. MDシミュレーションの実行
    print(f"\n--- MDシミュレーションを開始します ({N_RUN_STEPS} ステップ) ---")
    # md_results = md_relax(system)
    # 5. MDFeatureの設定
    md = MDFeature(
        integrator=integrator,
        n_run=N_RUN_STEPS,
        show_progress_bar=SHOW_PROGRESS,
        show_logger=SHOW_LOGGER,
        logger_interval=LOGGER_INTERVAL,
        traj_file_name=TRAJ_FILE_NAME,
        traj_freq=TRAJ_FREQ,
        estimator_fn=estimator_fn,
    )

    # 6. MDシミュレーションの実行
    print(f"\n--- MDシミュレーションを開始します ({N_RUN_STEPS} ステップ) ---")
    md_results = md(system)

    print("\n--- MDシミュレーションが正常に完了しました ---")
    print(f"最終的なトラジェクトリは '{TRAJ_FILE_NAME}' に保存されました。")
    print(f"最終ステップ: {system.current_total_step}, 最終時間: {system.current_time:.2f} fs")


if __name__ == "__main__":
    run_md_simulation()
# Out:
# システムを 600 K に初期化しました。
# --- Integrator: 'NVT_Berendsen' を選択しました ---
#
# --- MDシミュレーションを開始します (100000 ステップ) ---
#
# --- MDシミュレーションを開始します (100000 ステップ) ---
#   0%|          | 0/100000 [00:00<?, ?it/s]
# The MD trajectory will be saved at /home/jovyan/Kaori/MD/LiB_2/structure/pvdf_water_random_600K.traj.
# Note: The max disk size of /home/jovyan is about 98G.
# steps:     0  energy：-5.48 eV/atom  total energy: -5.40 eV/atom  temperature: 596.51 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:    50  energy：-2.12 eV/atom  total energy: 94.40 eV/atom  temperature: 746707.71 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:   100  energy：-2.67 eV/atom  total energy: 14.92 eV/atom  temperature: 136110.43 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:   150  energy：-3.10 eV/atom  total energy:  8.35 eV/atom  temperature: 88589.62 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:   200  energy：-3.34 eV/atom  total energy: -0.65 eV/atom  temperature: 20813.18 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:   250  energy：-3.47 eV/atom  total energy: -0.89 eV/atom  temperature: 19947.05 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:   300  energy：-3.58 eV/atom  total energy: -3.18 eV/atom  temperature: 3053.22 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:   350  energy：-3.67 eV/atom  total energy: -3.43 eV/atom  temperature: 1869.49 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:   400  energy：-3.69 eV/atom  total energy: -2.75 eV/atom  temperature: 7281.19 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:   450  energy：-3.71 eV/atom  total energy: -3.16 eV/atom  temperature: 4291.24 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:   500  energy：-3.71 eV/atom  total energy: -2.21 eV/atom  temperature: 11574.15 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:   550  energy：-3.73 eV/atom  total energy: -2.96 eV/atom  temperature: 5933.60 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:   600  energy：-3.75 eV/atom  total energy: -3.66 eV/atom  temperature: 695.03 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:   650  energy：-3.76 eV/atom  total energy: -3.68 eV/atom  temperature: 637.54 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:   700  energy：-3.76 eV/atom  total energy: -3.64 eV/atom  temperature: 912.17 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:   750  energy：-3.76 eV/atom  total energy: -3.68 eV/atom  temperature: 680.20 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:   800  energy：-3.77 eV/atom  total energy: -3.38 eV/atom  temperature: 2973.63 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:   850  energy：-3.77 eV/atom  total energy: -3.65 eV/atom  temperature: 941.88 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:   900  energy：-3.77 eV/atom  total energy: -3.59 eV/atom  temperature: 1377.22 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:   950  energy：-3.78 eV/atom  total energy: -3.55 eV/atom  temperature: 1788.45 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1000  energy：-3.78 eV/atom  total energy: -3.64 eV/atom  temperature: 1107.45 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1050  energy：-3.78 eV/atom  total energy: -3.70 eV/atom  temperature: 653.98 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1100  energy：-3.79 eV/atom  total energy: -3.65 eV/atom  temperature: 1036.83 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1150  energy：-3.77 eV/atom  total energy: -2.52 eV/atom  temperature: 9725.15 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1200  energy：-3.78 eV/atom  total energy: -3.62 eV/atom  temperature: 1239.84 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1250  energy：-3.78 eV/atom  total energy: -3.66 eV/atom  temperature: 975.38 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1300  energy：-3.78 eV/atom  total energy: -3.19 eV/atom  temperature: 4565.57 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1350  energy：-3.78 eV/atom  total energy: -3.71 eV/atom  temperature: 576.66 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1400  energy：-3.78 eV/atom  total energy: -3.69 eV/atom  temperature: 722.07 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1450  energy：-3.78 eV/atom  total energy: -3.24 eV/atom  temperature: 4126.21 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1500  energy：-3.77 eV/atom  total energy: -3.45 eV/atom  temperature: 2526.00 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1550  energy：-3.70 eV/atom  total energy:  2.75 eV/atom  temperature: 49920.35 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1600  energy：-3.72 eV/atom  total energy: -2.18 eV/atom  temperature: 11924.53 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1650  energy：-3.76 eV/atom  total energy: -3.65 eV/atom  temperature: 785.87 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1700  energy：-3.78 eV/atom  total energy: -3.63 eV/atom  temperature: 1155.19 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1750  energy：-3.78 eV/atom  total energy: -3.67 eV/atom  temperature: 841.98 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1800  energy：-3.79 eV/atom  total energy: -3.68 eV/atom  temperature: 851.92 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1850  energy：-3.78 eV/atom  total energy: -2.06 eV/atom  temperature: 13322.16 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1900  energy：-3.79 eV/atom  total energy: -3.59 eV/atom  temperature: 1552.84 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  1950  energy：-3.79 eV/atom  total energy: -3.67 eV/atom  temperature: 898.31 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2000  energy：-3.77 eV/atom  total energy: -2.44 eV/atom  temperature: 10308.32 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2050  energy：-3.78 eV/atom  total energy: -3.64 eV/atom  temperature: 1050.86 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2100  energy：-3.78 eV/atom  total energy: -3.60 eV/atom  temperature: 1421.96 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2150  energy：-3.77 eV/atom  total energy: -3.38 eV/atom  temperature: 3041.02 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2200  energy：-3.78 eV/atom  total energy: -3.31 eV/atom  temperature: 3618.41 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2250  energy：-3.77 eV/atom  total energy: -2.67 eV/atom  temperature: 8540.47 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2300  energy：-3.76 eV/atom  total energy: -3.15 eV/atom  temperature: 4734.63 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2350  energy：-3.78 eV/atom  total energy: -3.27 eV/atom  temperature: 3915.15 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2400  energy：-3.77 eV/atom  total energy: -3.38 eV/atom  temperature: 2998.61 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2450  energy：-3.79 eV/atom  total energy: -3.71 eV/atom  temperature: 611.30 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2500  energy：-3.79 eV/atom  total energy: -3.69 eV/atom  temperature: 766.93 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2550  energy：-3.80 eV/atom  total energy: -3.53 eV/atom  temperature: 2088.43 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2600  energy：-3.80 eV/atom  total energy: -3.19 eV/atom  temperature: 4782.05 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2650  energy：-3.80 eV/atom  total energy: -3.65 eV/atom  temperature: 1212.18 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2700  energy：-3.80 eV/atom  total energy: -2.60 eV/atom  temperature: 9297.33 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2750  energy：-3.80 eV/atom  total energy: -3.56 eV/atom  temperature: 1858.86 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2800  energy：-3.80 eV/atom  total energy: -3.65 eV/atom  temperature: 1120.21 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2850  energy：-3.81 eV/atom  total energy: -2.46 eV/atom  temperature: 10452.84 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2900  energy：-3.82 eV/atom  total energy: -3.67 eV/atom  temperature: 1138.01 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  2950  energy：-3.81 eV/atom  total energy: -3.63 eV/atom  temperature: 1437.42 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3000  energy：-3.82 eV/atom  total energy: -3.70 eV/atom  temperature: 893.94 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3050  energy：-3.82 eV/atom  total energy: -3.51 eV/atom  temperature: 2374.10 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3100  energy：-3.82 eV/atom  total energy: -3.75 eV/atom  temperature: 539.42 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3150  energy：-3.81 eV/atom  total energy: -3.63 eV/atom  temperature: 1443.33 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3200  energy：-3.81 eV/atom  total energy: -3.57 eV/atom  temperature: 1886.55 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3250  energy：-3.80 eV/atom  total energy: -2.85 eV/atom  temperature: 7359.52 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3300  energy：-3.81 eV/atom  total energy: -3.66 eV/atom  temperature: 1141.44 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3350  energy：-3.81 eV/atom  total energy: -3.66 eV/atom  temperature: 1197.89 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3400  energy：-3.81 eV/atom  total energy: -3.30 eV/atom  temperature: 3915.02 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3450  energy：-3.80 eV/atom  total energy: -3.58 eV/atom  temperature: 1672.98 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3500  energy：-3.80 eV/atom  total energy: -2.84 eV/atom  temperature: 7453.24 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3550  energy：-3.81 eV/atom  total energy: -3.61 eV/atom  temperature: 1520.68 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3600  energy：-3.81 eV/atom  total energy: -3.69 eV/atom  temperature: 914.18 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3650  energy：-3.81 eV/atom  total energy: -0.95 eV/atom  temperature: 22124.80 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3700  energy：-3.82 eV/atom  total energy: -3.39 eV/atom  temperature: 3315.22 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3750  energy：-3.82 eV/atom  total energy: -3.73 eV/atom  temperature: 715.96 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3800  energy：-3.82 eV/atom  total energy: -3.74 eV/atom  temperature: 579.11 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3850  energy：-3.82 eV/atom  total energy: -3.07 eV/atom  temperature: 5802.93 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3900  energy：-3.82 eV/atom  total energy: -3.59 eV/atom  temperature: 1787.00 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  3950  energy：-3.82 eV/atom  total energy: -3.63 eV/atom  temperature: 1447.93 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4000  energy：-3.82 eV/atom  total energy: -3.73 eV/atom  temperature: 683.97 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4050  energy：-3.82 eV/atom  total energy: -3.75 eV/atom  temperature: 543.67 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4100  energy：-3.82 eV/atom  total energy: -3.70 eV/atom  temperature: 986.66 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4150  energy：-3.82 eV/atom  total energy: -3.45 eV/atom  temperature: 2888.80 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4200  energy：-3.81 eV/atom  total energy: -2.81 eV/atom  temperature: 7738.94 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4250  energy：-3.82 eV/atom  total energy: -3.44 eV/atom  temperature: 2910.40 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4300  energy：-3.82 eV/atom  total energy: -3.66 eV/atom  temperature: 1255.95 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4350  energy：-3.83 eV/atom  total energy: -2.82 eV/atom  temperature: 7773.23 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4400  energy：-3.83 eV/atom  total energy: -3.72 eV/atom  temperature: 877.52 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4450  energy：-3.83 eV/atom  total energy: -3.44 eV/atom  temperature: 2977.81 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4500  energy：-3.83 eV/atom  total energy: -3.46 eV/atom  temperature: 2829.37 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4550  energy：-3.82 eV/atom  total energy: -3.69 eV/atom  temperature: 1034.82 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4600  energy：-3.82 eV/atom  total energy: -3.36 eV/atom  temperature: 3621.82 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4650  energy：-3.83 eV/atom  total energy: -3.63 eV/atom  temperature: 1485.85 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4700  energy：-3.81 eV/atom  total energy: -3.51 eV/atom  temperature: 2313.34 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4750  energy：-3.81 eV/atom  total energy: -3.16 eV/atom  temperature: 5041.45 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4800  energy：-3.80 eV/atom  total energy: -2.96 eV/atom  temperature: 6476.91 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4850  energy：-3.79 eV/atom  total energy: -1.69 eV/atom  temperature: 16176.22 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4900  energy：-3.81 eV/atom  total energy: -3.62 eV/atom  temperature: 1521.33 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  4950  energy：-3.82 eV/atom  total energy: -3.74 eV/atom  temperature: 638.73 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5000  energy：-3.82 eV/atom  total energy: -3.71 eV/atom  temperature: 815.30 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5050  energy：-3.82 eV/atom  total energy: -3.73 eV/atom  temperature: 726.04 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5100  energy：-3.83 eV/atom  total energy: -3.53 eV/atom  temperature: 2316.92 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5150  energy：-3.82 eV/atom  total energy: -3.74 eV/atom  temperature: 680.66 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5200  energy：-3.82 eV/atom  total energy: -3.73 eV/atom  temperature: 764.41 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5250  energy：-3.84 eV/atom  total energy: -3.73 eV/atom  temperature: 831.23 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5300  energy：-3.84 eV/atom  total energy: -3.71 eV/atom  temperature: 1014.88 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5350  energy：-3.83 eV/atom  total energy: -3.68 eV/atom  temperature: 1150.08 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5400  energy：-3.81 eV/atom  total energy: -3.05 eV/atom  temperature: 5827.85 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5450  energy：-3.83 eV/atom  total energy: -3.60 eV/atom  temperature: 1774.77 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5500  energy：-3.83 eV/atom  total energy: -3.71 eV/atom  temperature: 916.52 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5550  energy：-3.83 eV/atom  total energy: -3.71 eV/atom  temperature: 976.55 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5600  energy：-3.83 eV/atom  total energy: -3.68 eV/atom  temperature: 1177.55 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5650  energy：-3.83 eV/atom  total energy: -3.75 eV/atom  temperature: 566.24 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5700  energy：-3.82 eV/atom  total energy: -3.71 eV/atom  temperature: 896.94 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5750  energy：-3.81 eV/atom  total energy: -3.44 eV/atom  temperature: 2878.20 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5800  energy：-3.83 eV/atom  total energy: -3.65 eV/atom  temperature: 1350.08 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5850  energy：-3.83 eV/atom  total energy: -3.67 eV/atom  temperature: 1206.76 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5900  energy：-3.82 eV/atom  total energy: -3.74 eV/atom  temperature: 660.35 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  5950  energy：-3.83 eV/atom  total energy: -3.75 eV/atom  temperature: 629.34 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  6000  energy：-3.82 eV/atom  total energy: -3.75 eV/atom  temperature: 574.10 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  6050  energy：-3.82 eV/atom  total energy: -3.74 eV/atom  temperature: 671.60 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  6100  energy：-3.84 eV/atom  total energy: -3.74 eV/atom  temperature: 716.89 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  6150  energy：-3.84 eV/atom  total energy: -3.75 eV/atom  temperature: 717.32 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  6200  energy：-3.85 eV/atom  total energy: -3.77 eV/atom  temperature: 623.43 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  6250  energy：-3.85 eV/atom  total energy: -3.76 eV/atom  temperature: 696.68 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  6300  energy：-3.85 eV/atom  total energy: -3.79 eV/atom  temperature: 476.99 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  6350  energy：-3.85 eV/atom  total energy: -3.78 eV/atom  temperature: 579.33 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  6400  energy：-3.85 eV/atom  total energy: -3.76 eV/atom  temperature: 633.96 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  6450  energy：-3.83 eV/atom  total energy: -3.52 eV/atom  temperature: 2436.77 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  6500  energy：-3.84 eV/atom  total energy: -3.75 eV/atom  temperature: 729.96 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# steps:  6550  energy：-3.84 eV/atom  total energy: -3.61 eV/atom  temperature: 1742.37 K  volume: 36464 Ang^3  density: 1.514 g/cm^3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 208
#     204     print(f"最終ステップ: {system.current_total_step}, 最終時間: {system.current_time:.2f} fs")
#     207 if __name__ == "__main__":
# --> 208     run_md_simulation()
#
# Cell In[3], line 200, in run_md_simulation()
#     198 # 6. MDシミュレーションの実行
#     199 print(f"\n--- MDシミュレーションを開始します ({N_RUN_STEPS} ステップ) ---")
# --> 200 md_results = md(system)
#     202 print("\n--- MDシミュレーションが正常に完了しました ---")
#     203 print(f"最終的なトラジェクトリは '{TRAJ_FILE_NAME}' に保存されました。")
#
# File ~/.py311/lib/python3.11/site-packages/matlantis_features/features/base.py:131, in FeatureBaseCaller.call_decorate.<locals>.decorated(self, *args, **kwargs)
#     129 args_list = [copy_to_child_conversion(arg) for arg in args]
#     130 kwargs_new = {k: copy_to_child_conversion(v) for k, v in kwargs.items()}
# --> 131 res = derived_call(self, *args_list, **kwargs_new)
#     132 return res
#
# File ~/.py311/lib/python3.11/site-packages/matlantis_features/features/md/md.py:353, in MDFeature.__call__(self, system, extensions)
#     345     trajw = ASETrajWriter(
#     346         file_name=traj_fname,
#     347         write_mode=self.traj_write_mode,
#     348         props=self.traj_props,
#     349         save_init_frame=self.traj_init_frame,
#     350     )
#     351     sim.append_extension(trajw, self.traj_freq)
# --> 353 sim.run(n_run_steps=self.n_run)
#     355 if trajw is not None:
#     356     trajw.close()
#
# File ~/.py311/lib/python3.11/site-packages/matlantis_features/features/md/ase_simulation.py:192, in ASESimulation.run(self, n_run_steps)
#     187 if isinstance(self.integrator, NPTIntegrator):
#     188     # The ase.md.npt.NPT does not call the observers at step==0.
#     189     # To keep consistency with the other dynamics obj, we add the following line.
#     190     dyn.call_observers()
# --> 192 dyn.run(steps=n_run_steps)
#
# File ~/.py311/lib/python3.11/site-packages/ase/md/md.py:171, in MolecularDynamics.run(self, steps)
#     158 def run(self, steps=50):
#     159     """Run molecular dynamics algorithm.
#     160
#     161     Parameters
#    (...)
#     169         True if the maximum number of steps are reached.
#     170     """
# --> 171     return Dynamics.run(self, steps=steps)
#
# File ~/.py311/lib/python3.11/site-packages/ase/optimize/optimize.py:286, in Dynamics.run(self, steps)
#     268 def run(self, steps=DEFAULT_MAX_STEPS):
#     269     """Run dynamics algorithm.
#     270
#     271     This method will return when the forces on all individual
#    (...)
#     283         True if the forces on atoms are converged.
#     284     """
# --> 286     for converged in Dynamics.irun(self, steps=steps):
#     287         pass
#     288     return converged
#
# File ~/.py311/lib/python3.11/site-packages/ase/optimize/optimize.py:257, in Dynamics.irun(self, steps)
#     254 # run the algorithm until converged or max_steps reached
#     255 while not is_converged and self.nsteps < self.max_steps:
#     256     # compute the next step
# --> 257     self.step()
#     258     self.nsteps += 1
#     260     # log the step
#
# File ~/.py311/lib/python3.11/site-packages/ase/md/nvtberendsen.py:142, in NVTBerendsen.step(self, forces)
#     135 # We need to store the momenta on the atoms before calculating
#     136 # the forces, as in a parallel Asap calculation atoms may
#     137 # migrate during force calculations, and the momenta need to
#     138 # migrate along with the atoms.  For the same reason, we
#     139 # cannot use self.masses in the line above.
#     141 self.atoms.set_momenta(p)
# --> 142 forces = self.atoms.get_forces(md=True)
#     143 atoms.set_momenta(self.atoms.get_momenta() + 0.5 * self.dt * forces)
#     145 return forces
#
# File ~/.py311/lib/python3.11/site-packages/ase/atoms.py:829, in Atoms.get_forces(self, apply_constraint, md)
#     827 if self._calc is None:
#     828     raise RuntimeError('Atoms object has no calculator.')
# --> 829 forces = self._calc.get_forces(self)
#     831 if apply_constraint:
#     832     # We need a special md flag here because for MD we want
#     833     # to skip real constraints but include special "constraints"
#     834     # Like Hookean.
#     835     for constraint in self.constraints:
#
# File ~/.py311/lib/python3.11/site-packages/ase/calculators/abc.py:32, in GetPropertiesMixin.get_forces(self, atoms)
#      31 def get_forces(self, atoms=None):
# ---> 32     return self.get_property('forces', atoms)
#
# File ~/.py311/lib/python3.11/site-packages/ase/calculators/calculator.py:515, in BaseCalculator.get_property(self, name, atoms, allow_calculation)
#     512     if self.use_cache:
#     513         self.atoms = atoms.copy()
# --> 515     self.calculate(atoms, [name], system_changes)
#     517 if name not in self.results:
#     518     # For some reason the calculator was not able to do what we want,
#     519     # and that is OK.
#     520     raise PropertyNotImplementedError(
#     521         '{} not present in this ' 'calculation'.format(name)
#     522     )
#
# File ~/.py311/lib/python3.11/site-packages/pfp_api_client/pfp/calculators/ase_calculator.py:131, in ASECalculator.calculate(self, atoms, properties, system_changes)
#     128 try:
#     129     # check that we were not interrupted by SIGINT
#     130     InterruptWatcher.assert_not_interrupted()
# --> 131     return self._calculate(atoms, properties, system_changes)
#     132 finally:
#     133     self.concurrency_checker.release()
#
# File ~/.py311/lib/python3.11/site-packages/pfp_api_client/pfp/calculators/ase_calculator.py:183, in ASECalculator._calculate(self, atoms, properties, system_changes)
#     180 coordinates = self.atoms.get_positions()
#     181 properties_estimator = self.reverse_convert_properties(_properties)
# --> 183 self.results = self.estimator.estimate(
#     184     EstimatorSystem(
#     185         properties=properties_estimator,
#     186         coordinates=coordinates,
#     187         cell=cell_array,
#     188         atomic_numbers=atomic_numbers,
#     189         pbc=pbc,
#     190     )
#     191 )
#     193 # NOTE (himkt): to make compatible with ``SinglePointCalculator``.
#     194 for key, value in self.results.items():
#
# File ~/.py311/lib/python3.11/site-packages/pfp_api_client/pfp/estimator.py:926, in Estimator.estimate(self, args)
#     917     application_context = (
#     918         self.application_context
#     919         if self.application_context is not None
#    (...)
#     923         )
#     924     )
#     925     metadata.append((METADATA_APPLICATION_CONTEXT, application_context.lower()))
# --> 926     response = self.stub.Estimate(request, metadata=metadata)
#     927 else:
#     928     raise ValueError(
#     929         f"{_calc_mode} is not a valid calculation mode. "
#     930         f"Valid calculation modes are {', '.join(mode.name for mode in EstimatorCalcMode)}."
#     931     )
#
# File ~/.py311/lib/python3.11/site-packages/grpc/_interceptor.py:277, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     268 def __call__(
#     269     self,
#     270     request: Any,
#    (...)
#     275     compression: Optional[grpc.Compression] = None,
#     276 ) -> Any:
# --> 277     response, ignored_call = self._with_call(
#     278         request,
#     279         timeout=timeout,
#     280         metadata=metadata,
#     281         credentials=credentials,
#     282         wait_for_ready=wait_for_ready,
#     283         compression=compression,
#     284     )
#     285     return response
#
# File ~/.py311/lib/python3.11/site-packages/grpc/_interceptor.py:329, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     326     except Exception as exception:  # pylint:disable=broad-except
#     327         return _FailureOutcome(exception, sys.exc_info()[2])
# --> 329 call = self._interceptor.intercept_unary_unary(
#     330     continuation, client_call_details, request
#     331 )
#     332 return call.result(), call
#
# File ~/.py311/lib/python3.11/site-packages/pfp_api_client/utils/error_handler_client_interceptor.py:24, in ErrorHandlerClientInterceptor.intercept_unary_unary(self, continuation, client_call_details, request)
#      17 def intercept_unary_unary(
#      18     self,
#      19     continuation: Callable[[grpc.ClientCallDetails, Message], Any],
#      20     client_call_details: grpc.ClientCallDetails,
#      21     request: Message,
#      22 ) -> Union[grpc.Call, grpc.Future]:
#      23     return self._handle_response(
# ---> 24         client_call_details, continuation(client_call_details, request)
#      25     )
#
# File ~/.py311/lib/python3.11/site-packages/grpc/_interceptor.py:315, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     306 (
#     307     new_method,
#     308     new_timeout,
#    (...)
#     312     new_compression,
#     313 ) = _unwrap_client_call_details(new_details, client_call_details)
#     314 try:
# --> 315     response, call = self._thunk(new_method).with_call(
#     316         request,
#     317         timeout=new_timeout,
#     318         metadata=new_metadata,
#     319         credentials=new_credentials,
#     320         wait_for_ready=new_wait_for_ready,
#     321         compression=new_compression,
#     322     )
#     323     return _UnaryOutcome(response, call)
#     324 except grpc.RpcError as rpc_error:
#
# File ~/.py311/lib/python3.11/site-packages/grpc/_interceptor.py:343, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     334 def with_call(
#     335     self,
#     336     request: Any,
#    (...)
#     341     compression: Optional[grpc.Compression] = None,
#     342 ) -> Tuple[Any, grpc.Call]:
# --> 343     return self._with_call(
#     344         request,
#     345         timeout=timeout,
#     346         metadata=metadata,
#     347         credentials=credentials,
#     348         wait_for_ready=wait_for_ready,
#     349         compression=compression,
#     350     )
#
# File ~/.py311/lib/python3.11/site-packages/grpc/_interceptor.py:329, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     326     except Exception as exception:  # pylint:disable=broad-except
#     327         return _FailureOutcome(exception, sys.exc_info()[2])
# --> 329 call = self._interceptor.intercept_unary_unary(
#     330     continuation, client_call_details, request
#     331 )
#     332 return call.result(), call
#
# File ~/.py311/lib/python3.11/site-packages/pfp_api_client/utils/retry_client_interceptor.py:53, in RetryClientInterceptor.intercept_unary_unary(self, continuation, client_call_details, request)
#      50 def f() -> Union[grpc.Call, grpc.Future]:
#      51     return continuation(client_call_details, request)
# ---> 53 return self._retry(client_call_details, f)
#
# File ~/.py311/lib/python3.11/site-packages/pfp_api_client/utils/retry_client_interceptor.py:64, in RetryClientInterceptor._retry(self, client_call_details, f)
#      62 errors: Dict[StatusCode, int] = defaultdict(int)
#      63 while True:
# ---> 64     response = f()
#      65     code = response.code()
#      66     rate_limit_exceeded = False
#
# File ~/.py311/lib/python3.11/site-packages/pfp_api_client/utils/retry_client_interceptor.py:51, in RetryClientInterceptor.intercept_unary_unary.<locals>.f()
#      50 def f() -> Union[grpc.Call, grpc.Future]:
# ---> 51     return continuation(client_call_details, request)
#
# File ~/.py311/lib/python3.11/site-packages/grpc/_interceptor.py:315, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     306 (
#     307     new_method,
#     308     new_timeout,
#    (...)
#     312     new_compression,
#     313 ) = _unwrap_client_call_details(new_details, client_call_details)
#     314 try:
# --> 315     response, call = self._thunk(new_method).with_call(
#     316         request,
#     317         timeout=new_timeout,
#     318         metadata=new_metadata,
#     319         credentials=new_credentials,
#     320         wait_for_ready=new_wait_for_ready,
#     321         compression=new_compression,
#     322     )
#     323     return _UnaryOutcome(response, call)
#     324 except grpc.RpcError as rpc_error:
#
# File ~/.py311/lib/python3.11/site-packages/grpc/_channel.py:1195, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1183 def with_call(
#    1184     self,
#    1185     request: Any,
#    (...)
#    1190     compression: Optional[grpc.Compression] = None,
#    1191 ) -> Tuple[Any, grpc.Call]:
#    1192     (
#    1193         state,
#    1194         call,
# -> 1195     ) = self._blocking(
#    1196         request, timeout, metadata, credentials, wait_for_ready, compression
#    1197     )
#    1198     return _end_unary_response_blocking(state, call, True, None)
#
# File ~/.py311/lib/python3.11/site-packages/grpc/_channel.py:1162, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1145 state.target = _common.decode(self._target)
#    1146 call = self._channel.segregated_call(
#    1147     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1148     self._method,
#    (...)
#    1160     self._registered_call_handle,
#    1161 )
# -> 1162 event = call.next_event()
#    1163 _handle_event(event, state, self._response_deserializer)
#    1164 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:388, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:211, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:205, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:78, in grpc._cython.cygrpc._latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:61, in grpc._cython.cygrpc._internal_latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:42, in grpc._cython.cygrpc._next()
#
# File ~/.py311/lib/python3.11/site-packages/pfp_api_client/pfp/utils/interrupt_watcher.py:18, in InterruptWatcher.set_interrupt_flag(signum, frame)
#      15 InterruptWatcher.interrupted_evt.set()
#      16 # perform the default action, i.e., trigger a KeyboardInterrupt
#      17 # exception in the main thread
# ---> 18 signal.default_int_handler(signum, frame)
#
# KeyboardInterrupt:

# %%
from pfcc_extras import show_gui, view_ngl
from ase.io import Trajectory,read,write

# %%
# list=["NVE", "Langevin", "NVT_Berendsen", "NPT_Berendsen", "NPT"]

# show_gui(Trajectory(f"md_trajectory_{list[2]}.traj"))
# show_gui(Trajectory("/home/jovyan/Kaori/MD/LiB_2/structure/NVT_1500K1.traj"))
# show_gui(read("pvdf441_water.xyz"))
# show_gui(Trajectory("pvdf_water_opt2.traj"))
show_gui(Trajectory("pvdf_big222_water_600K.traj"))
# Out:
# VBox(children=(HBox(children=(NGLWidget(max_frame=381), Tab(children=(ViewerPanel(children=(VBox(children=(Dro…

# %%
from pfcc_extras import show_gui, view_ngl
from ase.io import Trajectory,read,write
pvdf2=read("pvdf_editopt2.xyz") 
pvdf=pvdf2.copy()
positions=pvdf.get_positions()
cell=[positions[:,1].max(),positions[:,2].max(),positions[:,0].max()]
-positions[:,0].min()
# Out:
# 4.64582949

# %%
# -*- coding: utf-8 -*-
import logging
import numpy as np
from ase import units
from ase.build import bulk
from ase.io import read, Trajectory, write
from ase.constraints import FixAtoms
import os
import time
from datetime import datetime
from sklearn.linear_model import LinearRegression
from matlantis_features.features.md import ASEMDSystem, LangevinIntegrator, MDFeature, MDExtensionBase, NPTIntegrator,AndersenIntegrator,NPTBerendsenIntegrator,NVTBerendsenIntegrator,VelocityVerletIntegrator
from matlantis_features.features.md.md_extensions import DeformScheduler
from pfp_api_client.pfp.estimator import Estimator, EstimatorCalcMode
from pfp_api_client.pfp.calculators.ase_calculator import ASECalculator
from matlantis_features.utils.calculators import get_calculator, pfp_estimator_fn
from matlantis_features.utils.atoms_util import convert_atoms_to_upper
from matlantis_features.atoms import MatlantisAtoms
import pandas as pd
from pathlib import Path
from ase import units
from ase.build import add_vacuum
import re

# Matlantis / PFP
from matlantis_features.features.md import (
    MDFeature,
    ASEMDSystem,
    VelocityVerletIntegrator,
    LangevinIntegrator,
    NVTBerendsenIntegrator,
    NPTBerendsenIntegrator,
    NPTIntegrator,
)
from matlantis_features.utils.calculators import pfp_estimator_fn
from pfp_api_client.pfp.estimator import EstimatorCalcMode

# --- ユーザー設定項目 (ここを編集してください) ---

# 1. 使用するIntegratorの種類を選択
#    選択肢: "NVE", "Langevin", "NVT_Berendsen", "NPT_Berendsen", "NPT"VelocityVerletIntegrator
# LangevinIntegrator
# AndersenIntegrator
# NVTBerendsenIntegrator
# NPTBerendsenIntegrator
# NPTIntegrator
INTEGRATOR_TYPE = "NVT_Berendsen"

# 2. 初期構造のファイルパスを指定 (ASEが読み込める形式ならOK)
#    例: "POSCAR", "input.cif", "structure.xyz"
#    指定しない場合は、Siのバルク結晶で計算します。
INPUT_STRUCTURE_FILE ="pvdf_opt2.traj"  # "your_structure_file.cif" など

# 3. MDシミュレーションの基本パラメータ
N_RUN_STEPS = 5000          # 実行するステップ数
TIME_STEP_FS = 1.0         # タイムステップ (fs)
TEMPERATURE_K = 2000        # 温度 (K)
PRESSURE_PA = 101325       # 圧力 (Pa) ※NPT系でのみ使用

# 4. ログとトラジェクトリの設定
SHOW_PROGRESS = True       # 進捗バーを表示するか
SHOW_LOGGER = True         # ログを標準出力に表示するか
LOGGER_INTERVAL = 50       # ログを出力する間隔 (ステップ数)
TRAJ_FILE_NAME = "NVT_2000K.traj"  # 出力トラジェクトリファイル名
TRAJ_FREQ = 50             # トラジェクトリを保存する間隔 (ステップ数)
vacuum=0.2
# 5. PFPモデルの計算設定
PFP_MODEL_VERSION = 'v7.0.0'
PFP_CALC_MODE = EstimatorCalcMode.CRYSTAL_U0

# --- 設定項目ここまで ---


def select_integrator(integrator_type: str):
    """
    指定された文字列に応じて、対応するIntegratorオブジェクトを返す関数。
    """
    print(f"--- Integrator: '{integrator_type}' を選択しました ---")
    
    # NPT系で使用する圧力 (ASE unitsに変換)
    pressure_au = PRESSURE_PA * units.Pascal

    if integrator_type == "NVE":
        # Microcanonical (NVE) ensemble using the Velocity Verlet algorithm
        return VelocityVerletIntegrator(timestep=TIME_STEP_FS)
        
    elif integrator_type == "Langevin":
        # Langevin dynamics for NVT ensemble
        return LangevinIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            friction=0.002  # 摩擦係数 (調整が必要な場合あり)
        )

    elif integrator_type == "NVT_Berendsen":
        # NVT ensemble with Berendsen thermostat
        return NVTBerendsenIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            taut=100.0 * units.fs  # 温度緩和時間
        )
        
    elif integrator_type == "NPT_Berendsen":
        # NPT ensemble with Berendsen thermostat and barostat
        return NPTBerendsenIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            pressure=pressure_au,
            taut=100.0 * units.fs,    # 温度緩和時間
            taup=1000.0 * units.fs    # 圧力緩和時間
        )
        
    elif integrator_type == "NPT":
        # NPT ensemble with Nosé-Hoover thermostat and Parrinello-Rahman barostat
        return NPTIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            pressure=pressure_au,
            ttime=25.0 * units.fs,    # 温度緩和時間 (Nosé-Hoover)
            pfactor=75.0 * units.fs  # 圧力緩和時間 (Parrinello-Rahman)
        )
        
    else:
        raise ValueError(f"エラー: 指定されたIntegrator '{integrator_type}' は不正です。")


def run_md_simulation():
    """
    設定に基づいてMDシミュレーションを実行するメイン関数。
    """
    # Matlantis-featuresのロガー設定
    logger = logging.getLogger("matlantis_features")
    logger.setLevel(logging.INFO)

    # 1. PFP計算器の準備
    estimator_fn = pfp_estimator_fn(model_version=PFP_MODEL_VERSION, calc_mode=PFP_CALC_MODE)
    # MOLECULE = Atoms('H2O')                 # 追加する分子
    # SPACING = 3.0                           # 分子間隔 (Å)
    # Z_OFFSET = 3.0 
    # atoms = Trajectory(INPUT_STRUCTURE_FILE)[-1]
    # positions = atoms.get_positions()
    # center_x, center_y, _ = positions.mean(axis=0)
    # max_z = np.max(positions[:, 2])
    # grid_center = np.array([center_x, center_y, max_z + Z_OFFSET])
    
    # # 3. 9分子のグリッドを作成
    # molecule_grid = Atoms()
    # MOLECULE.center()
    # offset = (3 - 1) / 2.0  # 3x3グリッドの中心化オフセット
    
    # for ix in range(3):
    #     for iy in range(3):
    #         pos = grid_center + np.array([(ix - offset) * SPACING, (iy - offset) * SPACING, 0.0])
    #         mol_copy = MOLECULE.copy()
    #         mol_copy.translate(pos)
    #         molecule_grid.extend(mol_copy)
    
    # # 4. 既存構造とグリッドを結合
    # atoms.extend(molecule_grid)
    # vacuum = 0.5
            
    # # 3. 全原子の座標を取得し、各軸の最小値と最大値を計算
    # positions = atoms.get_positions()
    # min_coords = positions.min(axis=0)
    # max_coords = positions.max(axis=0)
    
    # # 4. 新しいセルの大きさを計算
    # #    (分子の最大幅) + (両側の真空層)
    # cell_lengths = (max_coords - min_coords) + 2 * vacuum
    # new_cell = np.diag(cell_lengths)
    
    # # 5. 計算したセルをatomsオブジェクトに設定
    # atoms.set_cell(new_cell)
    # atoms.pbc=True
    # atoms.center()
    # write("pvdf_h2o.xyz",atoms)
    # # 2. 初期構造の準備
    # if INPUT_STRUCTURE_FILE:
    #     try:
    #         existing_atoms = Trajectory(INPUT_STRUCTURE_FILE)[-1]
    #         from ase import Atoms
    #         h2o=Atoms('H2O')
    #         NUM_WATER_MOLECULES = 5
    #         # 既存構造と最初の水分子とのZ方向の距離 (Å)
    #         INITIAL_SEPARATION = 3.0
    #         # 水分子同士のZ方向の距離 (Å)
    #         WATER_SEPARATION = 3.0
    #         # 
    #         NUM_COLUMNS_NX=5
    #         WATER_SEPARATION_XY=3.0
    #         water_layer = Atoms()
    #         h2o.center(about=(0,0,0))
    #         for i in range(NUM_WATER_MOLECULES):
    #             # グリッド上の位置を計算 (ix: 列, iy: 行)
    #             ix = i % NUM_COLUMNS_NX
    #             iy = i // NUM_COLUMNS_NX
            
    #             # 配置する座標を計算
    #             position = np.array([ix * WATER_SEPARATION_XY, iy * WATER_SEPARATION_XY, 0.0])
            
    #             # テンプレートをコピーして、計算した位置に移動
    #             h2o_to_add = h2o.copy()
    #             h2o_to_add.translate(position)
            
    #             # レイヤーに水分子を追加
    #             water_layer.extend(h2o_to_add)
    #             print(f"{i+1}個目の水分子を (x, y) ≈ ({position[0]:.1f}, {position[1]:.1f}) に配置しました。")
            
    #         # レイヤー全体の重心が原点に来るように移動
    #         water_layer.center(about=(0,0,0))
    #         print("作成した水分子レイヤーを X-Y 平面でセンタリングしました。")


    #         # from pfcc_extras import show_gui, view_ngl
    #         # from ase.io import Trajectory,read
    #         max_z_existing = np.max(existing_atoms.get_positions()[:, 2])
    #         print(f"既存構造のZ方向の最大座標: {max_z_existing:.2f} Å")
    #         # 4. 水分子をZ方向に追加していく
    #         # 最初の水分子を配置するZ座標を計算
    #         current_z = max_z_existing + INITIAL_SEPARATION
    #         h2o_to_add.positions[:, 2] += current_z
    #         existing_atoms.extend(h2o_to_add)
            # for i in range(NUM_WATER_MOLECULES):
            #     # 配置する水分子のコピーを作成
            #     h2o_to_add = h2o.copy()
            
            #     # 水分子をZ方向に移動させる
            #     # h2o_to_add.positions は (N, 3) のNumpy配列なので、
            #     # Z座標の列 ([:, 2]) に current_z を加算する
            #     h2o_to_add.positions[:, 2] += current_z
            
            #     # 既存のAtomsオブジェクトに水分子の原子を追加
    #         #     existing_atoms.extend(h2o_to_add)
            
    #         #     print(f"{i+1}個目の水分子を Z ≈ {current_z:.2f} Å の位置に追加しました。")
            
    #         #     # 次の水分子を配置するZ座標を更新
    #         #     current_z += WATER_SEPARATION
    #         atoms=existing_atoms.copy()
    #         # estimator = Estimator(model_version=PFP_MODEL_VERSION,calc_mode=PFP_CALC_MODE)
    #         # calculator = ASECalculator(estimator)
    #         # atoms.calc=calculator
    #         # atoms.get_stress()
    #         vacuum = 0.5
            
    #         # 3. 全原子の座標を取得し、各軸の最小値と最大値を計算
    #         positions = atoms.get_positions()
    #         min_coords = positions.min(axis=0)
    #         max_coords = positions.max(axis=0)
            
    #         # 4. 新しいセルの大きさを計算
    #         #    (分子の最大幅) + (両側の真空層)
    #         cell_lengths = (max_coords - min_coords) + 2 * vacuum
    #         new_cell = np.diag(cell_lengths)
            
    #         # 5. 計算したセルをatomsオブジェクトに設定
    #         atoms.set_cell(new_cell)
    #         atoms.pbc=True
            
    #         print(f"構造ファイル '{INPUT_STRUCTURE_FILE}' を読み込みました。原子数: {len(atoms)}")
    #     except FileNotFoundError:
    #         print(f"エラー: ファイル '{INPUT_STRUCTURE_FILE}' が見つかりません。")
    #         return
    # else:
    #     atoms = bulk("Si", cubic=True) * (2, 2, 2)
    #     print("構造ファイルが指定されなかったため、Siのバルク構造を生成しました。")
    
    # 3. MDシステムの初期化
    atoms=read("pvdf_opt.xyz")
    positions = atoms.get_positions()
    min_coords = positions.min(axis=0)
    max_coords = positions.max(axis=0)
    
    # 4. 新しいセルの大きさを計算
    #    (分子の最大幅) + (両側の真空層)
    cell_lengths = (max_coords - min_coords) + 2 * vacuum
    new_cell = np.diag(cell_lengths)
    
    # 5. 計算したセルをatomsオブジェクトに設定
    atoms.set_cell(new_cell)
    atoms.pbc=True
    system = ASEMDSystem(atoms)
    
    # 乱数シードを固定して温度を初期化（再現性のため）
    system.init_temperature(temperature=TEMPERATURE_K, stationary=True, rng=np.random.RandomState(seed=12345))
    print(f"システムを {TEMPERATURE_K} K に初期化しました。")

    # 4. Integratorの選択と準備
    try:
        integrator = select_integrator(INTEGRATOR_TYPE)
    except ValueError as e:
        print(e)
        return

    # 5. MDFeatureの設定
    md = MDFeature(
        integrator=integrator,
        n_run=N_RUN_STEPS,
        show_progress_bar=SHOW_PROGRESS,
        show_logger=SHOW_LOGGER,
        logger_interval=LOGGER_INTERVAL,
        traj_file_name=TRAJ_FILE_NAME,
        traj_freq=TRAJ_FREQ,
        estimator_fn=estimator_fn,
    )

    # 6. MDシミュレーションの実行
    print(f"\n--- MDシミュレーションを開始します ({N_RUN_STEPS} ステップ) ---")
    md_results = md(system)

    print("\n--- MDシミュレーションが正常に完了しました ---")
    print(f"最終的なトラジェクトリは '{TRAJ_FILE_NAME}' に保存されました。")
    print(f"最終ステップ: {system.current_total_step}, 最終時間: {system.current_time:.2f} fs")


if __name__ == "__main__":
    run_md_simulation()
# Out:
# システムを 2000 K に初期化しました。
# --- Integrator: 'NVT_Berendsen' を選択しました ---
#
# --- MDシミュレーションを開始します (5000 ステップ) ---
#   0%|          | 0/5000 [00:00<?, ?it/s]
# The MD trajectory will be saved at /home/jovyan/Kaori/MD/LiB_2/structure/NVT_2000K.traj.
# Note: The max disk size of /home/jovyan is about 98G.
# steps:     0  energy：-4.45 eV/atom  total energy: -4.19 eV/atom  temperature: 2009.13 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:    50  energy：-4.27 eV/atom  total energy: -4.03 eV/atom  temperature: 1895.69 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   100  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1959.39 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   150  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 2028.22 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   200  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 2035.42 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   250  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1959.59 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   300  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 2020.70 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   350  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1948.90 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   400  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 2005.46 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   450  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 2017.79 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   500  energy：-4.29 eV/atom  total energy: -4.02 eV/atom  temperature: 2036.34 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   550  energy：-4.29 eV/atom  total energy: -4.02 eV/atom  temperature: 2055.56 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   600  energy：-4.28 eV/atom  total energy: -4.03 eV/atom  temperature: 1981.73 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   650  energy：-4.29 eV/atom  total energy: -4.02 eV/atom  temperature: 2025.93 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   700  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1988.03 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   750  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 1964.92 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   800  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 2019.18 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   850  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1948.32 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   900  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 1974.44 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:   950  energy：-4.28 eV/atom  total energy: -4.03 eV/atom  temperature: 1956.49 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1000  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1929.11 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1050  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1972.26 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1100  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 2001.51 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1150  energy：-4.28 eV/atom  total energy: -4.01 eV/atom  temperature: 2071.87 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1200  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 2006.18 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1250  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 2043.17 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1300  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 1997.34 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1350  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1980.30 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1400  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1969.03 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1450  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 1987.85 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1500  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 2015.17 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1550  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 2069.52 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1600  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 1984.40 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1650  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1956.13 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1700  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 2013.86 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1750  energy：-4.26 eV/atom  total energy: -4.01 eV/atom  temperature: 1944.30 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1800  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 2010.81 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1850  energy：-4.27 eV/atom  total energy: -4.00 eV/atom  temperature: 2028.60 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1900  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1997.63 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  1950  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1957.06 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2000  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 2004.30 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2050  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 2059.62 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2100  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 2021.85 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2150  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 1975.04 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2200  energy：-4.26 eV/atom  total energy: -4.01 eV/atom  temperature: 1951.70 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2250  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 2017.10 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2300  energy：-4.26 eV/atom  total energy: -4.01 eV/atom  temperature: 1934.52 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2350  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1929.11 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2400  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 1992.02 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2450  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 1984.41 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2500  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 2011.17 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2550  energy：-4.28 eV/atom  total energy: -4.01 eV/atom  temperature: 2054.13 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2600  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 1961.49 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2650  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 2021.03 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2700  energy：-4.28 eV/atom  total energy: -4.01 eV/atom  temperature: 2046.07 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2750  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 2025.47 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2800  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 2016.62 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2850  energy：-4.28 eV/atom  total energy: -4.01 eV/atom  temperature: 2019.28 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2900  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 1990.54 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  2950  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1973.45 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3000  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 2002.36 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3050  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 1980.89 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3100  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 2023.29 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3150  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1954.03 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3200  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1956.74 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3250  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 2017.62 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3300  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1966.37 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3350  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 2010.61 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3400  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 2011.37 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3450  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 2029.32 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3500  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1946.00 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3550  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 2021.07 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3600  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 1990.61 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3650  energy：-4.28 eV/atom  total energy: -4.01 eV/atom  temperature: 2044.79 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3700  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 2005.73 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3750  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1996.09 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3800  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 2012.62 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3850  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1995.79 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3900  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 1988.92 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  3950  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 1971.49 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4000  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 2020.52 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4050  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 2037.42 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4100  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1973.83 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4150  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 1990.03 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4200  energy：-4.26 eV/atom  total energy: -4.01 eV/atom  temperature: 1901.84 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4250  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 2046.69 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4300  energy：-4.26 eV/atom  total energy: -4.01 eV/atom  temperature: 1913.93 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4350  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 2015.51 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4400  energy：-4.26 eV/atom  total energy: -4.01 eV/atom  temperature: 1917.40 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4450  energy：-4.28 eV/atom  total energy: -4.01 eV/atom  temperature: 2077.11 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4500  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 1985.45 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4550  energy：-4.27 eV/atom  total energy: -4.02 eV/atom  temperature: 1960.34 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4600  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 2014.18 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4650  energy：-4.26 eV/atom  total energy: -4.01 eV/atom  temperature: 1970.20 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4700  energy：-4.26 eV/atom  total energy: -4.01 eV/atom  temperature: 1971.37 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4750  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 1992.59 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4800  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 2026.58 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4850  energy：-4.28 eV/atom  total energy: -4.01 eV/atom  temperature: 2050.15 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4900  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 2018.44 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  4950  energy：-4.28 eV/atom  total energy: -4.02 eV/atom  temperature: 2006.65 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# steps:  5000  energy：-4.27 eV/atom  total energy: -4.01 eV/atom  temperature: 1978.70 K  volume: 14620 Ang^3  density: 0.720 g/cm^3
# --- MDシミュレーションが正常に完了しました ---
# 最終的なトラジェクトリは 'NVT_2000K.traj' に保存されました。
# 最終ステップ: 5000, 最終時間: 5000.00 fs

# %%
MOLECULE = Atoms('H2O')                 # 追加する分子
SPACING = 3.0                           # 分子間隔 (Å)
Z_OFFSET = 3.0 
atoms = Trajectory(INPUT_STRUCTURE_FILE)[-1]
positions = atoms.get_positions()
center_x, center_y, _ = positions.mean(axis=0)
max_z = np.max(positions[:, 2])
grid_center = np.array([center_x, center_y, max_z + Z_OFFSET])
print(atoms.get_chemical_symbols())
# 3. 9分子のグリッドを作成
molecule_grid = Atoms()
MOLECULE.center()
offset = (3 - 1) / 2.0  # 3x3グリッドの中心化オフセット

for ix in range(3):
    for iy in range(3):
        pos = grid_center + np.array([(ix - offset) * SPACING, (iy - offset) * SPACING, 0.0])
        mol_copy = MOLECULE.copy()
        mol_copy.translate(pos)
        molecule_grid=molecule_grid+mol_copy

# 4. 既存構造とグリッドを結合
atoms=atoms+molecule_grid
vacuum = 0.5
        
# 3. 全原子の座標を取得し、各軸の最小値と最大値を計算
positions = atoms.get_positions()
min_coords = positions.min(axis=0)
max_coords = positions.max(axis=0)
print(atoms.get_chemical_symbols())
# 4. 新しいセルの大きさを計算
#    (分子の最大幅) + (両側の真空層)
cell_lengths = (max_coords - min_coords) + 2 * vacuum
new_cell = np.diag(cell_lengths)

# 5. 計算したセルをatomsオブジェクトに設定
atoms.set_cell(new_cell)
atoms.pbc=True
atoms.center()
write("pvdf_h2o.xyz",atoms)
# Out:
# ['C', 'C', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'C', 'C', 'H', 'H', 'H', 'H', 'F', 'F', 'C', 'C', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'H', 'H', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'F', 'F', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'F', 'H', 'H', 'C', 'C', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'H', 'H', 'F', 'F', 'H', 'C', 'C', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'H', 'H', 'C', 'C', 'C', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'H', 'H', 'F', 'F', 'F', 'F', 'C', 'C', 'C', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'H', 'H', 'F', 'F', 'F', 'F', 'C', 'C', 'C', 'C', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'H', 'H', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'F', 'F', 'C', 'C', 'C', 'C', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'H', 'H', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'H', 'H', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'H', 'H', 'H', 'H', 'C', 'C', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'H', 'H', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'F', 'F', 'C', 'C', 'C', 'H', 'F', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'F', 'F', 'H', 'H', 'C', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'H', 'H', 'C', 'C', 'C', 'C', 'F', 'F', 'H', 'H', 'H', 'H', 'F', 'F', 'C', 'C', 'F', 'F', 'C', 'H', 'H', 'H', 'H', 'C', 'C', 'H', 'H', 'F', 'F', 'C', 'C', 'H', 'H', 'F', 'F', 'C', 'C', 'F', 'F', 'H', 'H', 'C', 'C', 'F', 'F', 'H', 'H', 'C', 'C', 'H', 'H', 'F', 'F', 'C', 'C', 'H', 'H', 'H', 'H', 'C', 'C', 'H', 'H', 'F', 'F']
# ['C', 'C', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'C', 'C', 'H', 'H', 'H', 'H', 'F', 'F', 'C', 'C', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'H', 'H', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'F', 'F', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'F', 'H', 'H', 'C', 'C', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'H', 'H', 'F', 'F', 'H', 'C', 'C', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'H', 'H', 'C', 'C', 'C', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'H', 'H', 'F', 'F', 'F', 'F', 'C', 'C', 'C', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'H', 'H', 'F', 'F', 'F', 'F', 'C', 'C', 'C', 'C', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'H', 'H', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'F', 'F', 'C', 'C', 'C', 'C', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'H', 'H', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'H', 'H', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'H', 'H', 'H', 'H', 'C', 'C', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'C', 'C', 'H', 'H', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'F', 'F', 'F', 'F', 'C', 'C', 'C', 'H', 'F', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'F', 'F', 'H', 'H', 'C', 'C', 'C', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'H', 'H', 'C', 'C', 'C', 'C', 'F', 'F', 'H', 'H', 'H', 'H', 'F', 'F', 'C', 'C', 'F', 'F', 'C', 'H', 'H', 'H', 'H', 'C', 'C', 'H', 'H', 'F', 'F', 'C', 'C', 'H', 'H', 'F', 'F', 'C', 'C', 'F', 'F', 'H', 'H', 'C', 'C', 'F', 'F', 'H', 'H', 'C', 'C', 'H', 'H', 'F', 'F', 'C', 'C', 'H', 'H', 'H', 'H', 'C', 'C', 'H', 'H', 'F', 'F', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O']

# %%
from ase import Atoms
h2o=Atoms('H2O')
from pfcc_extras import show_gui, view_ngl
from ase.io import Trajectory,read
show_gui(h2o)
# Out:
# VBox(children=(HBox(children=(NGLWidget(), Tab(children=(ViewerPanel(children=(VBox(children=(Dropdown(descrip…

# %%
help(atoms)
# Out:
# Help on Atoms in module ase.atoms object:
#
# class Atoms(builtins.object)
#  |  Atoms(symbols=None, positions=None, numbers=None, tags=None, momenta=None, masses=None, magmoms=None, charges=None, scaled_positions=None, cell=None, pbc=None, celldisp=None, constraint=None, calculator=None, info=None, velocities=None)
#  |
#  |  Atoms object.
#  |
#  |  The Atoms object can represent an isolated molecule, or a
#  |  periodically repeated structure.  It has a unit cell and
#  |  there may be periodic boundary conditions along any of the three
#  |  unit cell axes.
#  |  Information about the atoms (atomic numbers and position) is
#  |  stored in ndarrays.  Optionally, there can be information about
#  |  tags, momenta, masses, magnetic moments and charges.
#  |
#  |  In order to calculate energies, forces and stresses, a calculator
#  |  object has to attached to the atoms object.
#  |
#  |  Parameters
#  |  ----------
#  |  symbols : str | list[str] | list[Atom]
#  |      Chemical formula, a list of chemical symbols, or list of
#  |      :class:`~ase.Atom` objects (mutually exclusive with ``numbers``).
#  |
#  |      - ``'H2O'``
#  |      - ``'COPt12'``
#  |      - ``['H', 'H', 'O']``
#  |      - ``[Atom('Ne', (x, y, z)), ...]``
#  |
#  |  positions : list[tuple[float, float, float]]
#  |      Atomic positions in Cartesian coordinates
#  |      (mutually exclusive with ``scaled_positions``).
#  |      Anything that can be converted to an ndarray of shape (n, 3) works:
#  |      [(x0, y0, z0), (x1, y1, z1), ...].
#  |  scaled_positions : list[tuple[float, float, float]]
#  |      Atomic positions in units of the unit cell
#  |      (mutually exclusive with ``positions``).
#  |  numbers : list[int]
#  |      Atomic numbers (mutually exclusive with ``symbols``).
#  |  tags : list[int]
#  |      Special purpose tags.
#  |  momenta : list[tuple[float, float, float]]
#  |      Momenta for all atoms in Cartesian coordinates
#  |      (mutually exclusive with ``velocities``).
#  |  velocities : list[tuple[float, float, float]]
#  |      Velocities for all atoms in Cartesian coordinates
#  |      (mutually exclusive with ``momenta``).
#  |  masses : list[float]
#  |      Atomic masses in atomic units.
#  |  magmoms : list[float] | list[tuple[float, float, float]]
#  |      Magnetic moments.  Can be either a single value for each atom
#  |      for collinear calculations or three numbers for each atom for
#  |      non-collinear calculations.
#  |  charges : list[float]
#  |      Initial atomic charges.
#  |  cell : 3x3 matrix or length 3 or 6 vector, default: (0, 0, 0)
#  |      Unit cell vectors.  Can also be given as just three
#  |      numbers for orthorhombic cells, or 6 numbers, where
#  |      first three are lengths of unit cell vectors, and the
#  |      other three are angles between them (in degrees), in following order:
#  |      [len(a), len(b), len(c), angle(b,c), angle(a,c), angle(a,b)].
#  |      First vector will lie in x-direction, second in xy-plane,
#  |      and the third one in z-positive subspace.
#  |  celldisp : tuple[float, float, float], default: (0, 0, 0)
#  |      Unit cell displacement vector. To visualize a displaced cell
#  |      around the center of mass of a Systems of atoms.
#  |  pbc : bool | tuple[bool, bool, bool], default: False
#  |      Periodic boundary conditions flags.
#  |
#  |      - ``True``
#  |      - ``False``
#  |      - ``0``
#  |      - ``1``
#  |      - ``(1, 1, 0)``
#  |      - ``(True, False, False)``
#  |
#  |  constraint : constraint object(s)
#  |      One or more ASE constraints applied during structure optimization.
#  |  calculator : calculator object
#  |      ASE calculator to obtain energies and atomic forces.
#  |  info : dict | None, default: None
#  |      Dictionary with additional information about the system.
#  |      The following keys may be used by ASE:
#  |
#  |      - spacegroup: :class:`~ase.spacegroup.Spacegroup` instance
#  |      - unit_cell: 'conventional' | 'primitive' | int | 3 ints
#  |      - adsorbate_info: Information about special adsorption sites
#  |
#  |      Items in the info attribute survives copy and slicing and can
#  |      be stored in and retrieved from trajectory files given that the
#  |      key is a string, the value is JSON-compatible and, if the value is a
#  |      user-defined object, its base class is importable.  One should
#  |      not make any assumptions about the existence of keys.
#  |
#  |  Examples
#  |  --------
#  |  >>> from ase import Atom
#  |
#  |  N2 molecule (These three are equivalent):
#  |
#  |  >>> d = 1.104  # N2 bondlength
#  |  >>> a = Atoms('N2', [(0, 0, 0), (0, 0, d)])
#  |  >>> a = Atoms(numbers=[7, 7], positions=[(0, 0, 0), (0, 0, d)])
#  |  >>> a = Atoms([Atom('N', (0, 0, 0)), Atom('N', (0, 0, d))])
#  |
#  |  FCC gold:
#  |
#  |  >>> a = 4.05  # Gold lattice constant
#  |  >>> b = a / 2
#  |  >>> fcc = Atoms('Au',
#  |  ...             cell=[(0, b, b), (b, 0, b), (b, b, 0)],
#  |  ...             pbc=True)
#  |
#  |  Hydrogen wire:
#  |
#  |  >>> d = 0.9  # H-H distance
#  |  >>> h = Atoms('H', positions=[(0, 0, 0)],
#  |  ...           cell=(d, 0, 0),
#  |  ...           pbc=(1, 0, 0))
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, other)
#  |
#  |  __ase_optimizable__(self)
#  |
#  |  __delitem__(self, i)
#  |
#  |  __eq__(self, other)
#  |      Check for identity of two atoms objects.
#  |
#  |      Identity means: same positions, atomic numbers, unit cell and
#  |      periodic boundary conditions.
#  |
#  |  __getitem__(self, i)
#  |      Return a subset of the atoms.
#  |
#  |      i -- scalar integer, list of integers, or slice object
#  |      describing which atoms to return.
#  |
#  |      If i is a scalar, return an Atom object. If i is a list or a
#  |      slice, return an Atoms object with the same cell, pbc, and
#  |      other associated info as the original Atoms object. The
#  |      indices of the constraints will be shuffled so that they match
#  |      the indexing in the subset returned.
#  |
#  |  __iadd__(self, other)
#  |
#  |  __imul__(self, m)
#  |      In-place repeat of atoms.
#  |
#  |  __init__(self, symbols=None, positions=None, numbers=None, tags=None, momenta=None, masses=None, magmoms=None, charges=None, scaled_positions=None, cell=None, pbc=None, celldisp=None, constraint=None, calculator=None, info=None, velocities=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |
#  |  __len__(self)
#  |
#  |  __mul__(self, rep)
#  |
#  |  __ne__(self, other)
#  |      Check if two atoms objects are not equal.
#  |
#  |      Any differences in positions, atomic numbers, unit cell or
#  |      periodic boundary condtions make atoms objects not equal.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  append(self, atom)
#  |      Append atom to end.
#  |
#  |  center(self, vacuum=None, axis=(0, 1, 2), about=None)
#  |      Center atoms in unit cell.
#  |
#  |      Centers the atoms in the unit cell, so there is the same
#  |      amount of vacuum on all sides.
#  |
#  |      vacuum: float (default: None)
#  |          If specified adjust the amount of vacuum when centering.
#  |          If vacuum=10.0 there will thus be 10 Angstrom of vacuum
#  |          on each side.
#  |      axis: int or sequence of ints
#  |          Axis or axes to act on.  Default: Act on all axes.
#  |      about: float or array (default: None)
#  |          If specified, center the atoms about <about>.
#  |          I.e., about=(0., 0., 0.) (or just "about=0.", interpreted
#  |          identically), to center about the origin.
#  |
#  |  copy(self)
#  |      Return a copy.
#  |
#  |  edit(self)
#  |      Modify atoms interactively through ASE's GUI viewer.
#  |
#  |      Conflicts leading to undesirable behaviour might arise
#  |      when matplotlib has been pre-imported with certain
#  |      incompatible backends and while trying to use the
#  |      plot feature inside the interactive GUI. To circumvent,
#  |      please set matplotlib.use('gtk') before calling this
#  |      method.
#  |
#  |  euler_rotate(self, phi=0.0, theta=0.0, psi=0.0, center=(0, 0, 0))
#  |      Rotate atoms via Euler angles (in degrees).
#  |
#  |      See e.g http://mathworld.wolfram.com/EulerAngles.html for explanation.
#  |
#  |      Parameters:
#  |
#  |      center :
#  |          The point to rotate about. A sequence of length 3 with the
#  |          coordinates, or 'COM' to select the center of mass, 'COP' to
#  |          select center of positions or 'COU' to select center of cell.
#  |      phi :
#  |          The 1st rotation angle around the z axis.
#  |      theta :
#  |          Rotation around the x axis.
#  |      psi :
#  |          2nd rotation around the z axis.
#  |
#  |  extend(self, other)
#  |      Extend atoms object by appending atoms from *other*.
#  |
#  |  get_all_distances(self, mic=False, vector=False)
#  |      Return distances of all of the atoms with all of the atoms.
#  |
#  |      Use mic=True to use the Minimum Image Convention.
#  |
#  |  get_angle(self, a1, a2, a3, mic=False)
#  |      Get angle formed by three atoms.
#  |
#  |      Calculate angle in degrees between the vectors a2->a1 and
#  |      a2->a3.
#  |
#  |      Use mic=True to use the Minimum Image Convention and calculate the
#  |      angle across periodic boundaries.
#  |
#  |  get_angles(self, indices, mic=False)
#  |      Get angle formed by three atoms for multiple groupings.
#  |
#  |      Calculate angle in degrees between vectors between atoms a2->a1
#  |      and a2->a3, where a1, a2, and a3 are in each row of indices.
#  |
#  |      Use mic=True to use the Minimum Image Convention and calculate
#  |      the angle across periodic boundaries.
#  |
#  |  get_angular_momentum(self)
#  |      Get total angular momentum with respect to the center of mass.
#  |
#  |  get_array(self, name, copy=True)
#  |      Get an array.
#  |
#  |      Returns a copy unless the optional argument copy is false.
#  |
#  |  get_atomic_numbers(self)
#  |      Get integer array of atomic numbers.
#  |
#  |  get_calculator(self)
#  |      Get currently attached calculator object.
#  |
#  |      .. deprecated:: 3.20.0
#  |          Please use the equivalent ``atoms.calc`` instead of
#  |          ``atoms.get_calculator()``.
#  |
#  |  get_cell(self, complete=False)
#  |      Get the three unit cell vectors as a `class`:ase.cell.Cell` object.
#  |
#  |      The Cell object resembles a 3x3 ndarray, and cell[i, j]
#  |      is the jth Cartesian coordinate of the ith cell vector.
#  |
#  |  get_cell_lengths_and_angles(self)
#  |      Get unit cell parameters. Sequence of 6 numbers.
#  |
#  |      First three are unit cell vector lengths and second three
#  |      are angles between them::
#  |
#  |          [len(a), len(b), len(c), angle(b,c), angle(a,c), angle(a,b)]
#  |
#  |      in degrees.
#  |
#  |      .. deprecated:: 3.21.0
#  |          Please use ``atoms.cell.cellpar()`` instead
#  |
#  |  get_celldisp(self)
#  |      Get the unit cell displacement vectors.
#  |
#  |  get_center_of_mass(self, scaled=False, indices=None)
#  |      Get the center of mass.
#  |
#  |      Parameters
#  |      ----------
#  |      scaled : bool
#  |          If True, the center of mass in scaled coordinates is returned.
#  |      indices : list | slice | str, default: None
#  |          If specified, the center of mass of a subset of atoms is returned.
#  |
#  |  get_charges(self)
#  |      Get calculated charges.
#  |
#  |  get_chemical_formula(self, mode='hill', empirical=False)
#  |      Get the chemical formula as a string based on the chemical symbols.
#  |
#  |      Parameters:
#  |
#  |      mode: str
#  |          There are four different modes available:
#  |
#  |          'all': The list of chemical symbols are contracted to a string,
#  |          e.g. ['C', 'H', 'H', 'H', 'O', 'H'] becomes 'CHHHOH'.
#  |
#  |          'reduce': The same as 'all' where repeated elements are contracted
#  |          to a single symbol and a number, e.g. 'CHHHOCHHH' is reduced to
#  |          'CH3OCH3'.
#  |
#  |          'hill': The list of chemical symbols are contracted to a string
#  |          following the Hill notation (alphabetical order with C and H
#  |          first), e.g. 'CHHHOCHHH' is reduced to 'C2H6O' and 'SOOHOHO' to
#  |          'H2O4S'. This is default.
#  |
#  |          'metal': The list of chemical symbols (alphabetical metals,
#  |          and alphabetical non-metals)
#  |
#  |      empirical, bool (optional, default=False)
#  |          Divide the symbol counts by their greatest common divisor to yield
#  |          an empirical formula. Only for mode `metal` and `hill`.
#  |
#  |  get_chemical_symbols(self)
#  |      Get list of chemical symbol strings.
#  |
#  |      Equivalent to ``list(atoms.symbols)``.
#  |
#  |  get_dihedral(self, a0, a1, a2, a3, mic=False)
#  |      Calculate dihedral angle.
#  |
#  |      Calculate dihedral angle (in degrees) between the vectors a0->a1
#  |      and a2->a3.
#  |
#  |      Use mic=True to use the Minimum Image Convention and calculate the
#  |      angle across periodic boundaries.
#  |
#  |  get_dihedrals(self, indices, mic=False)
#  |      Calculate dihedral angles.
#  |
#  |      Calculate dihedral angles (in degrees) between the list of vectors
#  |      a0->a1 and a2->a3, where a0, a1, a2 and a3 are in each row of indices.
#  |
#  |      Use mic=True to use the Minimum Image Convention and calculate the
#  |      angles across periodic boundaries.
#  |
#  |  get_dipole_moment(self)
#  |      Calculate the electric dipole moment for the atoms object.
#  |
#  |      Only available for calculators which has a get_dipole_moment()
#  |      method.
#  |
#  |  get_distance(self, a0, a1, mic=False, vector=False)
#  |      Return distance between two atoms.
#  |
#  |      Use mic=True to use the Minimum Image Convention.
#  |      vector=True gives the distance vector (from a0 to a1).
#  |
#  |  get_distances(self, a, indices, mic=False, vector=False)
#  |      Return distances of atom No.i with a list of atoms.
#  |
#  |      Use mic=True to use the Minimum Image Convention.
#  |      vector=True gives the distance vector (from a to self[indices]).
#  |
#  |  get_forces(self, apply_constraint=True, md=False)
#  |      Calculate atomic forces.
#  |
#  |      Ask the attached calculator to calculate the forces and apply
#  |      constraints.  Use *apply_constraint=False* to get the raw
#  |      forces.
#  |
#  |      For molecular dynamics (md=True) we don't apply the constraint
#  |      to the forces but to the momenta. When holonomic constraints for
#  |      rigid linear triatomic molecules are present, ask the constraints
#  |      to redistribute the forces within each triple defined in the
#  |      constraints (required for molecular dynamics with this type of
#  |      constraints).
#  |
#  |  get_global_number_of_atoms(self)
#  |      Returns the global number of atoms in a distributed-atoms parallel
#  |      simulation.
#  |
#  |      DO NOT USE UNLESS YOU KNOW WHAT YOU ARE DOING!
#  |
#  |      Equivalent to len(atoms) in the standard ASE Atoms class.  You should
#  |      normally use len(atoms) instead.  This function's only purpose is to
#  |      make compatibility between ASE and Asap easier to maintain by having a
#  |      few places in ASE use this function instead.  It is typically only
#  |      when counting the global number of degrees of freedom or in similar
#  |      situations.
#  |
#  |  get_initial_charges(self)
#  |      Get array of initial charges.
#  |
#  |  get_initial_magnetic_moments(self)
#  |      Get array of initial magnetic moments.
#  |
#  |  get_kinetic_energy(self)
#  |      Get the kinetic energy.
#  |
#  |  get_kinetic_stress(self, voigt=True)
#  |      Calculate the kinetic part of the Virial stress tensor.
#  |
#  |  get_kinetic_stresses(self, voigt=True)
#  |      Calculate the kinetic part of the Virial stress of all the atoms.
#  |
#  |  get_magnetic_moment(self)
#  |      Get calculated total magnetic moment.
#  |
#  |  get_magnetic_moments(self)
#  |      Get calculated local magnetic moments.
#  |
#  |  get_masses(self)
#  |      Get array of masses in atomic mass units.
#  |
#  |  get_momenta(self)
#  |      Get array of momenta.
#  |
#  |  get_moments_of_inertia(self, vectors=False)
#  |      Get the moments of inertia along the principal axes.
#  |
#  |      The three principal moments of inertia are computed from the
#  |      eigenvalues of the symmetric inertial tensor. Periodic boundary
#  |      conditions are ignored. Units of the moments of inertia are
#  |      amu*angstrom**2.
#  |
#  |  get_number_of_atoms(self)
#  |      .. deprecated:: 3.18.1
#  |          You probably want ``len(atoms)``.  Or if your atoms are distributed,
#  |          use (and see) :func:`get_global_number_of_atoms()`.
#  |
#  |  get_number_of_degrees_of_freedom(self)
#  |      Calculate the number of degrees of freedom in the system.
#  |
#  |  get_pbc(self)
#  |      Get periodic boundary condition flags.
#  |
#  |  get_positions(self, wrap=False, **wrap_kw)
#  |      Get array of positions.
#  |
#  |      Parameters:
#  |
#  |      wrap: bool
#  |          wrap atoms back to the cell before returning positions
#  |      wrap_kw: (keyword=value) pairs
#  |          optional keywords `pbc`, `center`, `pretty_translation`, `eps`,
#  |          see :func:`ase.geometry.wrap_positions`
#  |
#  |  get_potential_energies(self)
#  |      Calculate the potential energies of all the atoms.
#  |
#  |      Only available with calculators supporting per-atom energies
#  |      (e.g. classical potentials).
#  |
#  |  get_potential_energy(self, force_consistent=False, apply_constraint=True)
#  |      Calculate potential energy.
#  |
#  |      Ask the attached calculator to calculate the potential energy and
#  |      apply constraints.  Use *apply_constraint=False* to get the raw
#  |      forces.
#  |
#  |      When supported by the calculator, either the energy extrapolated
#  |      to zero Kelvin or the energy consistent with the forces (the free
#  |      energy) can be returned.
#  |
#  |  get_properties(self, properties)
#  |      This method is experimental; currently for internal use.
#  |
#  |  get_reciprocal_cell(self)
#  |      Get the three reciprocal lattice vectors as a 3x3 ndarray.
#  |
#  |      Note that the commonly used factor of 2 pi for Fourier
#  |      transforms is not included here.
#  |
#  |      .. deprecated:: 3.21.0
#  |          Please use ``atoms.cell.reciprocal()``
#  |
#  |  get_scaled_positions(self, wrap=True)
#  |      Get positions relative to unit cell.
#  |
#  |      If wrap is True, atoms outside the unit cell will be wrapped into
#  |      the cell in those directions with periodic boundary conditions
#  |      so that the scaled coordinates are between zero and one.
#  |
#  |      If any cell vectors are zero, the corresponding coordinates
#  |      are evaluated as if the cell were completed using
#  |      ``cell.complete()``.  This means coordinates will be Cartesian
#  |      as long as the non-zero cell vectors span a Cartesian axis or
#  |      plane.
#  |
#  |  get_stress(self, voigt=True, apply_constraint=True, include_ideal_gas=False)
#  |      Calculate stress tensor.
#  |
#  |      Returns an array of the six independent components of the
#  |      symmetric stress tensor, in the traditional Voigt order
#  |      (xx, yy, zz, yz, xz, xy) or as a 3x3 matrix.  Default is Voigt
#  |      order.
#  |
#  |      The ideal gas contribution to the stresses is added if the
#  |      atoms have momenta and ``include_ideal_gas`` is set to True.
#  |
#  |  get_stresses(self, include_ideal_gas=False, voigt=True)
#  |      Calculate the stress-tensor of all the atoms.
#  |
#  |      Only available with calculators supporting per-atom energies and
#  |      stresses (e.g. classical potentials).  Even for such calculators
#  |      there is a certain arbitrariness in defining per-atom stresses.
#  |
#  |      The ideal gas contribution to the stresses is added if the
#  |      atoms have momenta and ``include_ideal_gas`` is set to True.
#  |
#  |  get_tags(self)
#  |      Get integer array of tags.
#  |
#  |  get_temperature(self)
#  |      Get the temperature in Kelvin.
#  |
#  |  get_total_energy(self)
#  |      Get the total energy - potential plus kinetic energy.
#  |
#  |  get_velocities(self)
#  |      Get array of velocities.
#  |
#  |  get_volume(self)
#  |      Get volume of unit cell.
#  |
#  |  has(self, name)
#  |      Check for existence of array.
#  |
#  |      name must be one of: 'tags', 'momenta', 'masses', 'initial_magmoms',
#  |      'initial_charges'.
#  |
#  |  iterimages(self)
#  |
#  |  new_array(self, name, a, dtype=None, shape=None)
#  |      Add new array.
#  |
#  |      If *shape* is not *None*, the shape of *a* will be checked.
#  |
#  |  pop(self, i=-1)
#  |      Remove and return atom at index *i* (default last).
#  |
#  |  rattle(self, stdev=0.001, seed=None, rng=None)
#  |      Randomly displace atoms.
#  |
#  |      This method adds random displacements to the atomic positions,
#  |      taking a possible constraint into account. The random numbers are
#  |      drawn from a normal distribution of standard deviation stdev.
#  |
#  |      By default, the random number generator always uses the same seed (42)
#  |      for repeatability. You can provide your own seed (an integer), or if you
#  |      want the randomness to be different each time you run a script, then
#  |      provide `rng=numpy.random`. For a parallel calculation, it is important
#  |      to use the same seed on all processors!
#  |
#  |  repeat(self, rep)
#  |      Create new repeated atoms object.
#  |
#  |      The *rep* argument should be a sequence of three positive
#  |      integers like *(2,3,1)* or a single integer (*r*) equivalent
#  |      to *(r,r,r)*.
#  |
#  |  rotate(self, a, v, center=(0, 0, 0), rotate_cell=False)
#  |      Rotate atoms based on a vector and an angle, or two vectors.
#  |
#  |      Parameters:
#  |
#  |      a = None:
#  |          Angle that the atoms is rotated around the vector 'v'. 'a'
#  |          can also be a vector and then 'a' is rotated
#  |          into 'v'.
#  |
#  |      v:
#  |          Vector to rotate the atoms around. Vectors can be given as
#  |          strings: 'x', '-x', 'y', ... .
#  |
#  |      center = (0, 0, 0):
#  |          The center is kept fixed under the rotation. Use 'COM' to fix
#  |          the center of mass, 'COP' to fix the center of positions or
#  |          'COU' to fix the center of cell.
#  |
#  |      rotate_cell = False:
#  |          If true the cell is also rotated.
#  |
#  |      Examples:
#  |
#  |      Rotate 90 degrees around the z-axis, so that the x-axis is
#  |      rotated into the y-axis:
#  |
#  |      >>> atoms = Atoms()
#  |      >>> atoms.rotate(90, 'z')
#  |      >>> atoms.rotate(90, (0, 0, 1))
#  |      >>> atoms.rotate(-90, '-z')
#  |      >>> atoms.rotate('x', 'y')
#  |      >>> atoms.rotate((1, 0, 0), (0, 1, 0))
#  |
#  |  rotate_dihedral(self, a1, a2, a3, a4, angle, mask=None, indices=None)
#  |      Rotate dihedral angle.
#  |
#  |      Same usage as in :meth:`ase.Atoms.set_dihedral`: Rotate a group by a
#  |      predefined dihedral angle, starting from its current configuration.
#  |
#  |  set_angle(self, a1, a2=None, a3=None, angle=None, mask=None, indices=None, add=False)
#  |      Set angle (in degrees) formed by three atoms.
#  |
#  |      Sets the angle between vectors *a2*->*a1* and *a2*->*a3*.
#  |
#  |      If *add* is `True`, the angle will be changed by the value given.
#  |
#  |      Same usage as in :meth:`ase.Atoms.set_dihedral`.
#  |      If *mask* and *indices*
#  |      are given, *indices* overwrites *mask*. If *mask* and *indices*
#  |      are not set, only *a3* is moved.
#  |
#  |  set_array(self, name, a, dtype=None, shape=None)
#  |      Update array.
#  |
#  |      If *shape* is not *None*, the shape of *a* will be checked.
#  |      If *a* is *None*, then the array is deleted.
#  |
#  |  set_atomic_numbers(self, numbers)
#  |      Set atomic numbers.
#  |
#  |  set_calculator(self, calc=None)
#  |      Attach calculator object.
#  |
#  |      .. deprecated:: 3.20.0
#  |          Please use the equivalent ``atoms.calc = calc`` instead of this
#  |          method.
#  |
#  |  set_cell(self, cell, scale_atoms=False, apply_constraint=True)
#  |      Set unit cell vectors.
#  |
#  |      Parameters:
#  |
#  |      cell: 3x3 matrix or length 3 or 6 vector
#  |          Unit cell.  A 3x3 matrix (the three unit cell vectors) or
#  |          just three numbers for an orthorhombic cell. Another option is
#  |          6 numbers, which describes unit cell with lengths of unit cell
#  |          vectors and with angles between them (in degrees), in following
#  |          order: [len(a), len(b), len(c), angle(b,c), angle(a,c),
#  |          angle(a,b)].  First vector will lie in x-direction, second in
#  |          xy-plane, and the third one in z-positive subspace.
#  |      scale_atoms: bool
#  |          Fix atomic positions or move atoms with the unit cell?
#  |          Default behavior is to *not* move the atoms (scale_atoms=False).
#  |      apply_constraint: bool
#  |          Whether to apply constraints to the given cell.
#  |
#  |      Examples:
#  |
#  |      Two equivalent ways to define an orthorhombic cell:
#  |
#  |      >>> atoms = Atoms('He')
#  |      >>> a, b, c = 7, 7.5, 8
#  |      >>> atoms.set_cell([a, b, c])
#  |      >>> atoms.set_cell([(a, 0, 0), (0, b, 0), (0, 0, c)])
#  |
#  |      FCC unit cell:
#  |
#  |      >>> atoms.set_cell([(0, b, b), (b, 0, b), (b, b, 0)])
#  |
#  |      Hexagonal unit cell:
#  |
#  |      >>> atoms.set_cell([a, a, c, 90, 90, 120])
#  |
#  |      Rhombohedral unit cell:
#  |
#  |      >>> alpha = 77
#  |      >>> atoms.set_cell([a, a, a, alpha, alpha, alpha])
#  |
#  |  set_celldisp(self, celldisp)
#  |      Set the unit cell displacement vectors.
#  |
#  |  set_center_of_mass(self, com, scaled=False)
#  |      Set the center of mass.
#  |
#  |      If scaled=True the center of mass is expected in scaled coordinates.
#  |      Constraints are considered for scaled=False.
#  |
#  |  set_chemical_symbols(self, symbols)
#  |      Set chemical symbols.
#  |
#  |  set_constraint(self, constraint=None)
#  |      Apply one or more constrains.
#  |
#  |      The *constraint* argument must be one constraint object or a
#  |      list of constraint objects.
#  |
#  |  set_dihedral(self, a1, a2, a3, a4, angle, mask=None, indices=None)
#  |      Set the dihedral angle (degrees) between vectors a1->a2 and
#  |      a3->a4 by changing the atom indexed by a4.
#  |
#  |      If mask is not None, all the atoms described in mask
#  |      (read: the entire subgroup) are moved. Alternatively to the mask,
#  |      the indices of the atoms to be rotated can be supplied. If both
#  |      *mask* and *indices* are given, *indices* overwrites *mask*.
#  |
#  |      **Important**: If *mask* or *indices* is given and does not contain
#  |      *a4*, *a4* will NOT be moved. In most cases you therefore want
#  |      to include *a4* in *mask*/*indices*.
#  |
#  |      Example: the following defines a very crude
#  |      ethane-like molecule and twists one half of it by 30 degrees.
#  |
#  |      >>> atoms = Atoms('HHCCHH', [[-1, 1, 0], [-1, -1, 0], [0, 0, 0],
#  |      ...                          [1, 0, 0], [2, 1, 0], [2, -1, 0]])
#  |      >>> atoms.set_dihedral(1, 2, 3, 4, 210, mask=[0, 0, 0, 1, 1, 1])
#  |
#  |  set_distance(self, a0, a1, distance, fix=0.5, mic=False, mask=None, indices=None, add=False, factor=False)
#  |      Set the distance between two atoms.
#  |
#  |      Set the distance between atoms *a0* and *a1* to *distance*.
#  |      By default, the center of the two atoms will be fixed.  Use
#  |      *fix=0* to fix the first atom, *fix=1* to fix the second
#  |      atom and *fix=0.5* (default) to fix the center of the bond.
#  |
#  |      If *mask* or *indices* are set (*mask* overwrites *indices*),
#  |      only the atoms defined there are moved
#  |      (see :meth:`ase.Atoms.set_dihedral`).
#  |
#  |      When *add* is true, the distance is changed by the value given.
#  |      In combination
#  |      with *factor* True, the value given is a factor scaling the distance.
#  |
#  |      It is assumed that the atoms in *mask*/*indices* move together
#  |      with *a1*. If *fix=1*, only *a0* will therefore be moved.
#  |
#  |  set_initial_charges(self, charges=None)
#  |      Set the initial charges.
#  |
#  |  set_initial_magnetic_moments(self, magmoms=None)
#  |      Set the initial magnetic moments.
#  |
#  |      Use either one or three numbers for every atom (collinear
#  |      or non-collinear spins).
#  |
#  |  set_masses(self, masses='defaults')
#  |      Set atomic masses in atomic mass units.
#  |
#  |      The array masses should contain a list of masses.  In case
#  |      the masses argument is not given or for those elements of the
#  |      masses list that are None, standard values are set.
#  |
#  |  set_momenta(self, momenta, apply_constraint=True)
#  |      Set momenta.
#  |
#  |  set_pbc(self, pbc)
#  |      Set periodic boundary condition flags.
#  |
#  |  set_positions(self, newpositions, apply_constraint=True)
#  |      Set positions, honoring any constraints. To ignore constraints,
#  |      use *apply_constraint=False*.
#  |
#  |  set_scaled_positions(self, scaled)
#  |      Set positions relative to unit cell.
#  |
#  |  set_tags(self, tags)
#  |      Set tags for all atoms. If only one tag is supplied, it is
#  |      applied to all atoms.
#  |
#  |  set_velocities(self, velocities)
#  |      Set the momenta by specifying the velocities.
#  |
#  |  todict(self)
#  |      For basic JSON (non-database) support.
#  |
#  |  translate(self, displacement)
#  |      Translate atomic positions.
#  |
#  |      The displacement argument can be a float an xyz vector or an
#  |      nx3 array (where n is the number of atoms).
#  |
#  |  wrap(self, **wrap_kw)
#  |      Wrap positions to unit cell.
#  |
#  |      Parameters:
#  |
#  |      wrap_kw: (keyword=value) pairs
#  |          optional keywords `pbc`, `center`, `pretty_translation`, `eps`,
#  |          see :func:`ase.geometry.wrap_positions`
#  |
#  |  write(self, filename, format=None, **kwargs)
#  |      Write atoms object to a file.
#  |
#  |      see ase.io.write for formats.
#  |      kwargs are passed to ase.io.write.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  fromdict(dct)
#  |      Rebuild atoms object from dictionary representation (todict).
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  number_of_lattice_vectors
#  |      Number of (non-zero) lattice vectors.
#  |
#  |      .. deprecated:: 3.21.0
#  |          Please use ``atoms.cell.rank`` instead
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  calc
#  |      Calculator object.
#  |
#  |  cell
#  |      The :class:`ase.cell.Cell` for direct manipulation.
#  |
#  |  constraints
#  |      Constraints of the atoms.
#  |
#  |  numbers
#  |      Attribute for direct manipulation of the atomic numbers.
#  |
#  |  pbc
#  |      Reference to pbc-flags for in-place manipulations.
#  |
#  |  positions
#  |      Attribute for direct manipulation of the positions.
#  |
#  |  symbols
#  |      Get chemical symbols as a :class:`ase.symbols.Symbols` object.
#  |
#  |      The object works like ``atoms.numbers`` except its values
#  |      are strings.  It supports in-place editing.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None
#  |
#  |  ase_objtype = 'atoms'

# %%
# write('data.lammps', atoms, format='lammps-data', atom_style='atomic')
help(write)
# Out:
# Help on function write in module ase.io.formats:
#
# write(filename: Union[str, pathlib.PurePath, IO], images: Union[ase.atoms.Atoms, Sequence[ase.atoms.Atoms]], format: str = None, parallel: bool = True, append: bool = False, **kwargs: Any) -> None
#     Write Atoms object(s) to file.
#
#     filename: str or file
#         Name of the file to write to or a file descriptor.  The name '-'
#         means standard output.
#     images: Atoms object or list of Atoms objects
#         A single Atoms object or a list of Atoms objects.
#     format: str
#         Used to specify the file-format.  If not given, the
#         file-format will be taken from suffix of the filename.
#     parallel: bool
#         Default is to write on master only.  Use parallel=False to write
#         from all slaves.
#     append: bool
#         Default is to open files in 'w' or 'wb' mode, overwriting
#         existing files.  In some cases opening the file in 'a' or 'ab'
#         mode (appending) is useful,
#         e.g. writing trajectories or saving multiple Atoms objects in one file.
#         WARNING: If the file format does not support multiple entries without
#         additional keywords/headers, files created using 'append=True'
#         might not be readable by any program! They will nevertheless be
#         written without error message.
#
#     The use of additional keywords is format specific. write() may
#     return an object after writing certain formats, but this behaviour
#     may change in the future.

# %%
import ase.io
from ase.io.lammpsdata import write_lammps_data # lammpsdataモジュールから直接インポート

# --- ユーザー設定項目 ---
XYZ_FILE = "pvdf_opt2.traj"
DATA_FILE = "data.pvdf"
INPUT_FILE = "in.pvdf_pyrolysis"
# VACUUM_LAYER = .0

# --- 1. XYZファイルを読み込み、LAMMPSデータファイルを作成 ---
try:
    atoms = Trajectory(XYZ_FILE)[-1]
    # atoms.center(vacuum=VACUUM_LAYER)
    atoms.pbc = True

    # write_lammps_data を直接使用
    print(f"writing lammps data to {DATA_FILE}")
    with open(DATA_FILE, 'w') as fd:
        write_lammps_data(fd, atoms, atom_style='full') # ファイルオブジェクト(fd)を渡す

    print(f"✅ LAMMPSデータファイル '{DATA_FILE}' を作成しました。")

except FileNotFoundError:
    print(f"❌ エラー: 入力ファイル '{XYZ_FILE}' が見つかりません。")
    exit()

# # --- 2. LAMMPSのインプットスクリプトを作成 (この部分は変更なし) ---
# lammps_input_script = f"""
# # LAMMPSインプットスクリプト: PVDFの熱分解シミュレーション
# # 生成元: ASE (Atomic Simulation Environment)

# # --- 1. 初期化 ---
# units          real
# boundary       p p p
# atom_style     full

# # --- 2. 構造読み込み ---
# read_data      {DATA_FILE}

# # (以下、前回のスクリプトと同様...)
# # --- 3. 力場設定 (ReaxFF) ---
# pair_style     reaxff NULL checkqeq no
# pair_coeff     * * ffield.reax.CHON C H F
# fix            1 all qeq/reaxff 1 0.0 10.0 1.0e-6 reaxff

# # --- 4. エネルギー最小化 ---
# minimize       1.0e-4 1.0e-6 1000 10000

# # --- 5. アニーリング (200K -> 500K -> 200Kを10サイクル) ---
# timestep       0.2
# thermo         1000
# print "========= Starting Annealing Loop ========="
# variable       i loop 10
# label          loop_anneal
#   fix          anneal all nvt temp 200.0 500.0 100.0
#   run          5000
#   unfix        anneal
#   fix          anneal all nvt temp 500.0 200.0 100.0
#   run          5000
#   unfix        anneal
#   next         i
# jump           SELF loop_anneal
# print "========= Annealing Finished ========="

# # --- 6. 昇温プロセス ---
# reset_timestep 0
# thermo         5000
# fix            heating all nvt temp 200.0 3000.0 100.0
# dump           heating_dump all custom 5000 dump.heating.*.lammpstrj id type x y z
# run            100000
# unfix          heating
# undump         heating_dump

# # --- 7. 定温プロセス (NVT) ---
# reset_timestep 0
# thermo         10000
# fix            isothermal all nvt temp 3000.0 3000.0 100.0
# dump           iso_dump all custom 10000 dump.isothermal.*.lammpstrj id type x y z
# run            30000000

# print "========= Simulation Finished ========="
# """

# with open(INPUT_FILE, 'w') as f:
#     f.write(lammps_input_script)

print(f"✅ LAMMPSインプットスクリプト '{INPUT_FILE}' を作成しました。")
# Out:
# writing lammps data to data.pvdf
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[38], line 19
#      17     print(f"writing lammps data to {DATA_FILE}")
#      18     with open(DATA_FILE, 'w') as fd:
# ---> 19         write_lammps_data(fd, atoms, atom_style='full') # ファイルオブジェクト(fd)を渡す
#      21     print(f"✅ LAMMPSデータファイル '{DATA_FILE}' を作成しました。")
#      23 except FileNotFoundError:
#
# File ~/.py311/lib/python3.11/site-packages/ase/utils/__init__.py:599, in iofunction.__call__.<locals>.iofunc(file, *args, **kwargs)
#     597     else:
#     598         fd = file
# --> 599     obj = func(fd, *args, **kwargs)
#     600     return obj
#     601 finally:
#
# File ~/.py311/lib/python3.11/site-packages/ase/io/lammpsdata.py:484, in write_lammps_data(fd, atoms, specorder, reduce_cell, force_skew, prismobj, write_image_flags, masses, velocities, units, bonds, atom_style)
#     481     fd.write(f'{n_bond_types} bond types\n\n')
#     483 if prismobj is None:
# --> 484     prismobj = Prism(atoms.get_cell(), reduce_cell=reduce_cell)
#     486 # Get cell parameters and convert from ASE units to LAMMPS units
#     487 xhi, yhi, zhi, xy, xz, yz = convert(
#     488     prismobj.get_lammps_prism(), 'distance', 'ASE', units)
#
# File ~/.py311/lib/python3.11/site-packages/ase/calculators/lammps/coordinatetransform.py:155, in Prism.__init__(self, cell, pbc, reduce_cell, tolerance)
#     142 def __init__(
#     143     self,
#     144     cell: np.ndarray,
#    (...)
#     152     # LAMMPS requires positive diagonal elements of the triangular matrix.
#     153     # The diagonals of `lammps_tilt` are always positive by construction.
#     154     self.lammps_tilt = calc_rotated_cell(cell)
# --> 155     self.rot_mat = np.linalg.solve(self.lammps_tilt, cell).T
#     156     self.ase_cell = cell
#     157     self.tolerance = tolerance
#
# File ~/.py311/lib/python3.11/site-packages/numpy/linalg/linalg.py:409, in solve(a, b)
#     407 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     408 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 409 r = gufunc(a, b, signature=signature, extobj=extobj)
#     411 return wrap(r.astype(result_t, copy=False))
#
# File ~/.py311/lib/python3.11/site-packages/numpy/linalg/linalg.py:112, in _raise_linalgerror_singular(err, flag)
#     111 def _raise_linalgerror_singular(err, flag):
# --> 112     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %%
# -*- coding: utf-8 -*-
import logging
import numpy as np
from ase import units
from ase.build import bulk
from ase.io import Trajectory
import os

# Matlantis / PFP
from matlantis_features.features.md import (
    MDFeature,
    ASEMDSystem,
    VelocityVerletIntegrator,
    LangevinIntegrator,
    NVTBerendsenIntegrator,
    NPTBerendsenIntegrator,
    NPTIntegrator,
)
from matlantis_features.utils.calculators import pfp_estimator_fn
from pfp_api_client.pfp.estimator import EstimatorCalcMode

# --- ユーザー設定項目 (ここを編集してください) ---

# 1. 順番に実行したいIntegratorのリスト
#    選択肢: "NVE", "Langevin", "NVT_Berendsen", "NPT_Berendsen", "NPT""Langevin"VelocityVerletIntegrator
# LangevinIntegrator
# AndersenIntegrator
# NVTBerendsenIntegrator
# NPTBerendsenIntegrator
# NPTIntegrator
INTEGRATORS_TO_RUN = [
    # "NVE",
    # "Langevin"
    "NVT_Berendsen",
    # "NPT_Berendsen",
    # "NPT",
]

# 2. 初期構造のファイルパスを指定
INPUT_STRUCTURE_FILE = "pvdf_opt2.traj"

# 3. MDシミュレーションの共通パラメータ
N_RUN_STEPS = 5000          # 実行するステップ数
TIME_STEP_FS = 1.0         # タイムステップ (fs)
TEMPERATURE_K = 800        # 温度 (K)
PRESSURE_PA = 101325       # 圧力 (Pa) ※NPT系でのみ使用

# 4. ログとトラジェクトリの共通設定
SHOW_PROGRESS = True       # 進捗バーを表示するか
SHOW_LOGGER = True         # ログを標準出力に表示するか
LOGGER_INTERVAL = 50       # ログを出力する間隔 (ステップ数)
TRAJ_FREQ = 50             # トラジェクトリを保存する間隔 (ステップ数)

# 5. PFPモデルの計算設定
PFP_MODEL_VERSION = 'v7.0.0'
PFP_CALC_MODE = EstimatorCalcMode.CRYSTAL_U0

# --- 設定項目ここまで ---


def select_integrator(integrator_type: str):
    """
    指定された文字列に応じて、対応するIntegratorオブジェクトを返す関数。
    """
    # NPT系で使用する圧力 (ASE unitsに変換)
    pressure_au = PRESSURE_PA * units.Pascal

    if integrator_type == "NVE":
        # Microcanonical (NVE) ensemble using the Velocity Verlet algorithm
        return VelocityVerletIntegrator(timestep=TIME_STEP_FS)
        
    elif integrator_type == "Langevin":
        # Langevin dynamics for NVT ensemble
        return LangevinIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            friction=0.002
        )

    elif integrator_type == "NVT_Berendsen":
        # NVT ensemble with Berendsen thermostat
        return NVTBerendsenIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            taut=100.0 * units.fs
        )
        
    elif integrator_type == "NPT_Berendsen":
        # NPT ensemble with Berendsen thermostat and barostat
        return NPTBerendsenIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            pressure=pressure_au,
            taut=100.0 * units.fs,
            taup=1000.0 * units.fs
        )
        
    elif integrator_type == "NPT":
        # NPT ensemble with Nosé-Hoover and Parrinello-Rahman
        return NPTIntegrator(
            timestep=TIME_STEP_FS,
            temperature=TEMPERATURE_K,
            pressure=pressure_au,
            ttime=25.0 * units.fs,
            pfactor=75.0 * units.fs
        )
        
    else:
        raise ValueError(f"エラー: 指定されたIntegrator '{integrator_type}' は不正です。")


def run_md_simulation(initial_atoms, integrator_type, traj_file_name):
    """
    単一のMDシミュレーションを実行する関数。
    """
    print(f"\n{'='*60}")
    print(f" Integrator: '{integrator_type}' のシミュレーションを開始します。")
    print(f" 出力ファイル: '{traj_file_name}'")
    print(f"{'='*60}")

    # PFP計算器の準備
    estimator_fn = pfp_estimator_fn(model_version=PFP_MODEL_VERSION, calc_mode=PFP_CALC_MODE)

    # MDシステムの初期化
    system = ASEMDSystem(initial_atoms)
    
    # 乱数シードを固定して温度を初期化（再現性のため）
    system.init_temperature(temperature=TEMPERATURE_K, stationary=True, rng=np.random.RandomState(seed=12345))
    print(f"システムを {TEMPERATURE_K} K に初期化しました。")

    # Integratorの選択
    try:
        integrator = select_integrator(integrator_type)
    except ValueError as e:
        print(e)
        return

    # MDFeatureの設定
    md = MDFeature(
        integrator=integrator,
        n_run=N_RUN_STEPS,
        show_progress_bar=SHOW_PROGRESS,
        show_logger=SHOW_LOGGER,
        logger_interval=LOGGER_INTERVAL,
        traj_file_name=traj_file_name,
        traj_freq=TRAJ_FREQ,
        traj_props=["energy", "forces", "stress"], # stressを保存
        estimator_fn=estimator_fn,
    )

    # MDシミュレーションの実行
    md_results = md(system)

    print(f"\n--- Integrator: '{integrator_type}' のシミュレーションが完了しました ---")


def main():
    """
    設定に基づいて、複数のMDシミュレーションを逐次実行するメイン関数。
    """
    # Matlantis-featuresのロガー設定
    logging.basicConfig(level=logging.INFO)
    logger = logging.getLogger("matlantis_features")
    logger.setLevel(logging.INFO)

    # 初期構造の準備
    print("--- 初期構造の準備 ---")
    if INPUT_STRUCTURE_FILE and os.path.exists(INPUT_STRUCTURE_FILE):
        # トラジェクトリファイルの最後のフレームを読み込む
        atoms = Trajectory(INPUT_STRUCTURE_FILE)[-1]
        
        # 真空層を追加し、セルを再設定
        vacuum = 0.5
        positions = atoms.get_positions()
        min_coords = positions.min(axis=0)
        max_coords = positions.max(axis=0)
        cell_lengths = (max_coords - min_coords) + 2 * vacuum
        atoms.set_cell(np.diag(cell_lengths))
        atoms.pbc = True
        
        print(f"構造ファイル '{INPUT_STRUCTURE_FILE}' の最終フレームを読み込み、セルを再設定しました。原子数: {len(atoms)}")
    else:
        print(f"エラー: ファイル '{INPUT_STRUCTURE_FILE}' が見つかりません。")
        return

    # 定義されたIntegratorで順番に計算を実行
    for integrator_name in INTEGRATORS_TO_RUN:
        output_filename = f"md_trajectory_{integrator_name}.traj"
        # 毎回同じ初期構造のコピーを渡す
        run_md_simulation(atoms.copy(), integrator_name, output_filename)
        
    print(f"\n{'='*60}")
    print("全てのシミュレーションが完了しました。")
    print(f"{'='*60}")

if __name__ == "__main__":
    main()
# Out:
# INFO:ga4mp.ga4mp:Sending POST to: https://www.google-analytics.com/mp/collect
# INFO:ga4mp.ga4mp:Batch Number: 1
# INFO:ga4mp.ga4mp:Status code: 204
# --- 初期構造の準備 ---
# 構造ファイル 'pvdf_opt2.traj' の最終フレームを読み込み、セルを再設定しました。原子数: 601
#
# ============================================================
#  Integrator: 'NVT_Berendsen' のシミュレーションを開始します。
#  出力ファイル: 'md_trajectory_NVT_Berendsen.traj'
# ============================================================
# システムを 800 K に初期化しました。
#   0%|          | 0/5000 [00:00<?, ?it/s]
# WARNING:matlantis_features.features.md.md:The MD trajectory will be saved at /home/jovyan/Kaori/MD/LiB_2/structure/md_trajectory_NVT_Berendsen.traj.
# WARNING:matlantis_features.features.md.md:Note: The max disk size of /home/jovyan is about 98G.
# INFO:matlantis_features.features.md.md:steps:     0  energy：-4.47 eV/atom  total energy: -4.37 eV/atom  temperature: 803.65 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:    50  energy：-4.40 eV/atom  total energy: -4.30 eV/atom  temperature: 773.61 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:   100  energy：-4.40 eV/atom  total energy: -4.30 eV/atom  temperature: 823.19 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:   150  energy：-4.40 eV/atom  total energy: -4.30 eV/atom  temperature: 764.67 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:   200  energy：-4.40 eV/atom  total energy: -4.30 eV/atom  temperature: 788.24 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:   250  energy：-4.40 eV/atom  total energy: -4.30 eV/atom  temperature: 777.82 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:   300  energy：-4.40 eV/atom  total energy: -4.29 eV/atom  temperature: 814.61 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:   350  energy：-4.40 eV/atom  total energy: -4.30 eV/atom  temperature: 813.33 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:   400  energy：-4.40 eV/atom  total energy: -4.30 eV/atom  temperature: 782.56 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:   450  energy：-4.40 eV/atom  total energy: -4.30 eV/atom  temperature: 799.74 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:   500  energy：-4.40 eV/atom  total energy: -4.30 eV/atom  temperature: 786.63 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:   550  energy：-4.41 eV/atom  total energy: -4.30 eV/atom  temperature: 802.89 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:   600  energy：-4.40 eV/atom  total energy: -4.30 eV/atom  temperature: 795.13 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:   650  energy：-4.40 eV/atom  total energy: -4.30 eV/atom  temperature: 780.03 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:   700  energy：-4.40 eV/atom  total energy: -4.30 eV/atom  temperature: 788.60 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:   750  energy：-4.41 eV/atom  total energy: -4.30 eV/atom  temperature: 816.50 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:   800  energy：-4.41 eV/atom  total energy: -4.30 eV/atom  temperature: 789.04 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:   850  energy：-4.40 eV/atom  total energy: -4.30 eV/atom  temperature: 807.97 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:   900  energy：-4.40 eV/atom  total energy: -4.30 eV/atom  temperature: 798.49 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:   950  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 806.15 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1000  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 820.32 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1050  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 780.74 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1100  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 773.42 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1150  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 788.67 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1200  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 809.71 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1250  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 810.35 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1300  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 819.97 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1350  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 804.77 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1400  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 780.45 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1450  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 786.23 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1500  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 784.31 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1550  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 792.22 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1600  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 785.83 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1650  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 806.31 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1700  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 755.45 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1750  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 812.98 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1800  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 771.67 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1850  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 814.77 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1900  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 782.13 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  1950  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 808.90 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2000  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 805.97 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2050  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 805.24 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2100  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 812.41 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2150  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 783.14 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2200  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 825.98 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2250  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 796.18 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2300  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 776.91 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2350  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 812.60 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2400  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 818.97 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2450  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 761.95 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2500  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 791.03 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2550  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 808.89 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2600  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 788.93 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2650  energy：-4.42 eV/atom  total energy: -4.32 eV/atom  temperature: 806.06 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2700  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 795.30 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2750  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 819.18 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2800  energy：-4.42 eV/atom  total energy: -4.32 eV/atom  temperature: 804.77 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2850  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 814.11 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2900  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 781.71 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  2950  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 787.87 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3000  energy：-4.42 eV/atom  total energy: -4.32 eV/atom  temperature: 808.59 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3050  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 784.17 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3100  energy：-4.42 eV/atom  total energy: -4.32 eV/atom  temperature: 790.73 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3150  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 808.29 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3200  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 797.54 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3250  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 818.75 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3300  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 798.45 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3350  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 810.16 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3400  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 807.94 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3450  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 798.64 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3500  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 794.20 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3550  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 797.71 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3600  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 810.90 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3650  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 795.48 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3700  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 789.99 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3750  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 781.15 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3800  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 825.21 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3850  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 791.86 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3900  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 778.34 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  3950  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 810.08 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4000  energy：-4.42 eV/atom  total energy: -4.32 eV/atom  temperature: 798.94 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4050  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 807.96 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4100  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 783.27 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4150  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 769.64 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4200  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 811.54 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4250  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 799.09 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4300  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 785.25 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4350  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 780.46 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4400  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 801.29 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4450  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 790.05 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4500  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 817.76 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4550  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 796.27 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4600  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 818.07 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4650  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 778.29 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4700  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 799.83 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4750  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 767.69 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4800  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 799.35 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4850  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 798.58 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4900  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 762.46 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  4950  energy：-4.42 eV/atom  total energy: -4.31 eV/atom  temperature: 811.91 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# INFO:matlantis_features.features.md.md:steps:  5000  energy：-4.41 eV/atom  total energy: -4.31 eV/atom  temperature: 798.42 K  volume: 15768 Ang^3  density: 0.668 g/cm^3
# --- Integrator: 'NVT_Berendsen' のシミュレーションが完了しました ---
#
# ============================================================
# 全てのシミュレーションが完了しました。
# ============================================================

# %%
atoms = Trajectory(INPUT_STRUCTURE_FILE)[-1]
estimator = Estimator(model_version=PFP_MODEL_VERSION,calc_mode=PFP_CALC_MODE)
calculator = ASECalculator(estimator)
atoms.calc=calculator
atoms.get_stress()
# Out:
# ---------------------------------------------------------------------------
# PropertyNotImplementedError               Traceback (most recent call last)
# Cell In[12], line 5
#       3 calculator = ASECalculator(estimator)
#       4 atoms.calc=calculator
# ----> 5 atoms.get_stress()
#
# File ~/.py311/lib/python3.11/site-packages/ase/atoms.py:861, in Atoms.get_stress(self, voigt, apply_constraint, include_ideal_gas)
#     858 if self._calc is None:
#     859     raise RuntimeError('Atoms object has no calculator.')
# --> 861 stress = self._calc.get_stress(self)
#     862 shape = stress.shape
#     864 if shape == (3, 3):
#     865     # Convert to the Voigt form before possibly applying
#     866     # constraints and adding the dynamic part of the stress
#     867     # (the "ideal gas contribution").
#
# File ~/.py311/lib/python3.11/site-packages/ase/calculators/abc.py:35, in GetPropertiesMixin.get_stress(self, atoms)
#      34 def get_stress(self, atoms=None):
# ---> 35     return self.get_property('stress', atoms)
#
# File ~/.py311/lib/python3.11/site-packages/ase/calculators/calculator.py:520, in BaseCalculator.get_property(self, name, atoms, allow_calculation)
#     515     self.calculate(atoms, [name], system_changes)
#     517 if name not in self.results:
#     518     # For some reason the calculator was not able to do what we want,
#     519     # and that is OK.
# --> 520     raise PropertyNotImplementedError(
#     521         '{} not present in this ' 'calculation'.format(name)
#     522     )
#     524 result = self.results[name]
#     525 if isinstance(result, np.ndarray):
#
# PropertyNotImplementedError: stress not present in this calculation

# %%
# help(pfp_estimator_fn)
import pfp_api_client
help(pfp_api_client.pfp.estimator.EstimatorCalcMode)
# Out:
# Help on class EstimatorCalcMode in module pfp_api_client.pfp.estimator:
#
# class EstimatorCalcMode(enum.Enum)
#  |  EstimatorCalcMode(value, names=None, *, module=None, qualname=None, type=None, start=1, boundary=None)
#  |
#  |  Enum class which is used to determine `calc_mode` in `Estimator`.
#  |
#  |  :ivar PBE: This mode corresponds to DFT calculations with plane wave basis sets.
#  |  :ivar PBE_PLUS_D3: PBE mode with D3 correction enabled.     This mode corresponds to DFT calculations with plane wave basis sets,     plus a D3 dispersion correction.
#  |  :ivar PBE_U: PBE mode with Hubbard U parameter. This mode corresponds      to DFT calculations with plane wave basis sets.
#  |  :ivar PBE_U_PLUS_D3: PBE_U mode with D3 correction enabled.     This mode corresponds to DFT calculations with plane wave basis sets,     plus a D3 dispersion correction.
#  |  :ivar WB97XD: This mode corresponds to DFT calculations with local basis     sets.
#  |
#  |  Method resolution order:
#  |      EstimatorCalcMode
#  |      enum.Enum
#  |      builtins.object
#  |
#  |  Data and other attributes defined here:
#  |
#  |  CRYSTAL = <EstimatorCalcMode.CRYSTAL: 'crystal'>
#  |
#  |  CRYSTAL_PLUS_D3 = <EstimatorCalcMode.CRYSTAL_PLUS_D3: 'crystal_plus_d3...
#  |
#  |  CRYSTAL_U0 = <EstimatorCalcMode.CRYSTAL_U0: 'crystal_u0'>
#  |
#  |  CRYSTAL_U0_PLUS_D3 = <EstimatorCalcMode.CRYSTAL_U0_PLUS_D3: 'crystal_u...
#  |
#  |  MOLECULE = <EstimatorCalcMode.MOLECULE: 'molecule'>
#  |
#  |  PBE = <EstimatorCalcMode.PBE: 'pbe'>
#  |
#  |  PBE_PLUS_D3 = <EstimatorCalcMode.PBE_PLUS_D3: 'pbe_plus_d3'>
#  |
#  |  PBE_U = <EstimatorCalcMode.PBE_U: 'pbe_u'>
#  |
#  |  PBE_U_PLUS_D3 = <EstimatorCalcMode.PBE_U_PLUS_D3: 'pbe_u_plus_d3'>
#  |
#  |  R2SCAN = <EstimatorCalcMode.R2SCAN: 'r2scan'>
#  |
#  |  R2SCAN_PLUS_D3 = <EstimatorCalcMode.R2SCAN_PLUS_D3: 'r2scan_plus_d3'>
#  |
#  |  WB97XD = <EstimatorCalcMode.WB97XD: 'wb97xd'>
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from enum.Enum:
#  |
#  |  name
#  |      The name of the Enum member.
#  |
#  |  value
#  |      The value of the Enum member.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from enum.EnumType:
#  |
#  |  __contains__(member)
#  |      Return True if member is a member of this enum
#  |      raises TypeError if member is not an enum member
#  |
#  |      note: in 3.12 TypeError will no longer be raised, and True will also be
#  |      returned if member is the value of a member in this enum
#  |
#  |  __getitem__(name)
#  |      Return the member matching `name`.
#  |
#  |  __iter__()
#  |      Return members in definition order.
#  |
#  |  __len__()
#  |      Return the number of members (no aliases)
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from enum.EnumType:
#  |
#  |  __members__
#  |      Returns a mapping of member name->value.
#  |
#  |      This mapping lists all enum members, including aliases. Note that this
#  |      is a read-only view of the internal mapping.

# %%
atoms=read("pvdf_opt.xyz")

# %%
from ase.io import read, Trajectory, write
from ase.constraints import FixAtoms
import numpy as np
import os
import time
from datetime import datetime
from sklearn.linear_model import LinearRegression
from matlantis_features.features.md import ASEMDSystem, LangevinIntegrator, MDFeature, MDExtensionBase, NPTIntegrator,AndersenIntegrator,NPTBerendsenIntegrator,NVTBerendsenIntegrator,VelocityVerletIntegrator
from matlantis_features.features.md.md_extensions import DeformScheduler
from pfp_api_client.pfp.estimator import Estimator, EstimatorCalcMode
from pfp_api_client.pfp.calculators.ase_calculator import ASECalculator
from matlantis_features.utils.calculators import get_calculator, pfp_estimator_fn
from matlantis_features.utils.atoms_util import convert_atoms_to_upper
from matlantis_features.atoms import MatlantisAtoms
import numpy as np
import pandas as pd
from pathlib import Path
from ase import units
from ase.build import add_vacuum
import re

# %%
import ase
from ase.build import bulk
from ase.md.velocitydistribution import MaxwellBoltzmannDistribution,Stationary
from ase.md.npt import NPT
from ase.md import MDLogger
from ase import units
from time import perf_counter

calc_type = "PFP"
# calc_type = "PFP"

if calc_type == "EMT":
    # ASAP3-EMT calculator
    from asap3 import EMT
    calculator = EMT()
elif calc_type == "PFP":
    # PFP calculator
    from pfp_api_client.pfp.estimator import Estimator, EstimatorCalcMode
    from pfp_api_client.pfp.calculators.ase_calculator import ASECalculator
    estimator = Estimator(model_version="v2.0.0",calc_mode=EstimatorCalcMode.CRYSTAL_U0)
    calculator = ASECalculator(estimator)
else:
    raise ValueError(f"Wrong calc_type = {calc_type}!")


# Set up a crystal
# atoms_in = bulk("Cu",cubic=True)
# atoms_in *= 3
# atoms_in.pbc = True
# print("atoms_in = ",atoms_in)

# input parameters
time_step    = 1.0    # fsec
temperature = 1000    # Kelvin
num_md_steps = 20000 
num_interval = 10

sigma   = 1.0     # External pressure in bar
ttime   = 20.0    # Time constant in fs
pfactor = 2e6     # Barostat parameter in GPa
temperature_list = [200,300,400,500,600,700,800,900,1000]

# Print statements
def print_dyn():
    imd = dyn.get_number_of_steps()
    etot  = atoms.get_total_energy()
    temp_K = atoms.get_temperature()
    stress = atoms.get_stress(include_ideal_gas=True)/units.GPa
    stress_ave = (stress[0]+stress[1]+stress[2])/3.0 
    elapsed_time = perf_counter() - start_time
    print(f"  {imd: >3}   {etot:.3f}    {temp_K:.2f}    {stress_ave:.2f}  {stress[0]:.2f}  {stress[1]:.2f}  {stress[2]:.2f}  {stress[3]:.2f}  {stress[4]:.2f}  {stress[5]:.2f}    {elapsed_time:.3f}")

    
# run MD
for i,temperature in enumerate(temperature_list):
    print("i,temperature = ",i,temperature)

    print(f"sigma = {sigma:.1e} bar")
    print(f"ttime = {ttime:.3f} fs")
    print(f"pfactor = {pfactor:.3f} GPa*fs^2")

    temperature_str = str(int(temperature)).zfill(4)
    output_filename = f"pvdf_npt.traj"
    log_filename = output_filename + ".log"
    traj_filename = output_filename + ".traj"
    print("log_filename = ",log_filename)
    print("traj_filename = ",traj_filename)
    
    atoms = read("pvdf_opt.xyz")
    atoms.calc = calculator
    
    # Set the momenta corresponding to T=300K
    MaxwellBoltzmannDistribution(atoms, temperature_K=temperature,force_temp=True)
    Stationary(atoms)
    
    dyn = NPT(atoms,
          time_step*units.fs,
          temperature_K = temperature,
          externalstress = sigma*units.bar,
          ttime = ttime*units.fs,
          pfactor = pfactor*units.GPa*(units.fs**2),
          logfile = log_filename,
          trajectory = traj_filename,
          loginterval=num_interval
          )
    
    print_interval = 1000 if calc_type == "EMT" else num_interval
    dyn.attach(print_dyn, interval=print_interval)
    dyn.attach(MDLogger(dyn, atoms, log_filename, header=True, stress=True, peratom=True, mode="a"), interval=num_interval)

    # Now run the dynamics
    start_time = perf_counter()
    print(f"    imd     Etot(eV)    T(K)    stress(mean,xx,yy,zz,yz,xz,xy)(GPa)  elapsed_time(sec)")
    dyn.run(num_md_steps)
# Out:
# i,temperature =  0 200
# sigma = 1.0e+00 bar
# ttime = 20.000 fs
# pfactor = 2000000.000 GPa*fs^2
# log_filename =  pvdf_npt.traj.log
# traj_filename =  pvdf_npt.traj.traj
#     imd     Etot(eV)    T(K)    stress(mean,xx,yy,zz,yz,xz,xy)(GPa)  elapsed_time(sec)
# /home/jovyan/.py311/lib/python3.11/site-packages/ase/md/npt.py:698: RuntimeWarning: divide by zero encountered in scalar divide
#   self.pfact = 1.0 / (self.pfactor_given * linalg.det(self._getbox()))
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[3], line 94
#      92 start_time = perf_counter()
#      93 print(f"    imd     Etot(eV)    T(K)    stress(mean,xx,yy,zz,yz,xz,xy)(GPa)  elapsed_time(sec)")
# ---> 94 dyn.run(num_md_steps)
#
# File ~/.py311/lib/python3.11/site-packages/ase/md/npt.py:315, in NPT.run(self, steps)
#     301 def run(self, steps):
#     302     """Perform a number of time steps.
#     303
#     304     Parameters
#    (...)
#     312         True if the maximum number of steps are reached.
#     313     """
# --> 315     for complete in self.irun(steps):
#     316         pass
#     317     return complete
#
# File ~/.py311/lib/python3.11/site-packages/ase/md/npt.py:293, in NPT.irun(self, steps)
#     279 """Run dynamics algorithm as generator.
#     280
#     281 Parameters
#    (...)
#     289     True if the maximum number of steps are reached.
#     290 """
#     292 if not self.initialized:
# --> 293     self.initialize()
#     294 else:
#     295     if self.have_the_atoms_been_changed():
#
# File ~/.py311/lib/python3.11/site-packages/ase/md/npt.py:416, in NPT.initialize(self)
#     412 if not self._istriangular(self.h):
#     413     raise NotImplementedError(
#     414         f"Can (so far) only operate on lists of atoms where the "
#     415         f"computational box is a triangular matrix. {self.h}")
# --> 416 self.inv_h = linalg.inv(self.h)
#     417 # The contents of the q arrays should migrate in parallel simulations.
#     418 # self._make_special_q_arrays()
#     419 self.q = np.dot(self.atoms.get_positions(), self.inv_h) - 0.5
#
# File ~/.py311/lib/python3.11/site-packages/numpy/linalg/linalg.py:561, in inv(a)
#     559 signature = 'D->D' if isComplexType(t) else 'd->d'
#     560 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 561 ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     562 return wrap(ainv.astype(result_t, copy=False))
#
# File ~/.py311/lib/python3.11/site-packages/numpy/linalg/linalg.py:112, in _raise_linalgerror_singular(err, flag)
#     111 def _raise_linalgerror_singular(err, flag):
# --> 112     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %%
# from pfp_estimator.core import pfp_estimator_fn
# from pfp_estimator.estimator import EstimatorCalcMode
# from pfp_estimator.features import MDFeature
# from openmm import LangevinIntegrator

# Assuming `system` is already defined (e.g., from an OpenMM setup)
# and `equil_file` is the desired trajectory file name prefix.
atoms=read("pvdf_opt.xyz")
system=MatlantisAtoms.from_ase_atoms(atoms)
# Define the list of calculation modes you want to run.
calc_modes_to_run = [
    'pbe',
    'pbe_plus_d3',
    'wb97xd',
    'crystal_u0_plus_d3'
]

# Create the integrator
# integrator = LangevinIntegrator(timestep=1.0, temperature=900.0)

# Loop through each calculation mode
for mode_str in calc_modes_to_run:
    print(f"Starting simulation with calc_mode: {mode_str}")

    # Instantiate the estimator function for the current mode
    estimator_fn = pfp_estimator_fn(model_version='v7.0.0', calc_mode=mode_str)
    atoms = atoms_in.copy()
    atoms.calc = calculator
    
    # Set the momenta corresponding to T=300K
    MaxwellBoltzmannDistribution(atoms, temperature_K=temperature,force_temp=True)
    Stationary(atoms)
    
    dyn = NPT(atoms,
          time_step*units.fs,
          temperature_K = temperature,
          externalstress = sigma*units.bar,
          ttime = ttime*units.fs,
          pfactor = pfactor*units.GPa*(units.fs**2),
          logfile = log_filename,
          trajectory = traj_filename,
          loginterval=num_interval
          )
    
    print_interval = 1000 if calc_type == "EMT" else num_interval
    # dyn.attach(print_dyn, interval=print_interval)
    # dyn.attach(MDLogger(dyn, atoms, log_filename, header=True, stress=True, peratom=True, mode="a"), interval=num_interval)

    # Create the MD feature with the new estimator function
    md = MDFeature(
        integrator,
        n_run=4000,
        traj_file_name=f"pvdfcalc_{mode_str}.traj",
        traj_freq=100,
        estimator_fn=estimator_fn
    )

    # Run the MD simulation
    md(system)
    print(f"Simulation with {mode_str} completed.")
# Out:
# Starting simulation with calc_mode: crystal_u0_plus_d3
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 38
#      29 md = MDFeature(
#      30     integrator,
#      31     n_run=4000,
#    (...)
#      34     estimator_fn=estimator_fn
#      35 )
#      37 # Run the MD simulation
# ---> 38 md(system)
#      39 print(f"Simulation with {mode_str} completed.")
#
# File ~/.py311/lib/python3.11/site-packages/matlantis_features/features/base.py:131, in FeatureBaseCaller.call_decorate.<locals>.decorated(self, *args, **kwargs)
#     129 args_list = [copy_to_child_conversion(arg) for arg in args]
#     130 kwargs_new = {k: copy_to_child_conversion(v) for k, v in kwargs.items()}
# --> 131 res = derived_call(self, *args_list, **kwargs_new)
#     132 return res
#
# File ~/.py311/lib/python3.11/site-packages/matlantis_features/features/md/md.py:315, in MDFeature.__call__(self, system, extensions)
#     301 def __call__(
#     302     self, system: MDSystemBase, extensions: Optional[MDExtensionList] = None
#     303 ) -> MDFeatureResult:
#     304     """Run the MD simulation.
#     305
#     306     Args:
#    (...)
#     313         MDFeatureResult : Result object for the MD simulation.
#     314     """
# --> 315     sim = ASESimulation(system, self.integrator, estimator_fn=self.estimator_fn)
#     317     if self.show_pbar or self.show_logger:
#     318         sim.append_extension(
#     319             _ProgressExtension(
#     320                 self, self.show_pbar, self.tqdm_options, self.show_logger, self.logger_interval
#     321             ),
#     322             1,
#     323         )
#
# File ~/.py311/lib/python3.11/site-packages/matlantis_features/features/md/ase_simulation.py:142, in ASESimulation.__init__(self, system, integrator, estimator_fn)
#     131 if isinstance(self.integrator, NPTIntegrator) and not np.all(
#     132     atoms.get_cell()[[1, 2, 2], [0, 0, 1]] == 0.0
#     133 ):
#     134     raise ValueError(
#     135         "The NPTIntegrator requires the `cell` of the input structure to be an upper "
#     136         "triangular matrix. You can simply rotate the MatlantisAtoms to make its cell a "
#    (...)
#     139         "`matlantis_features.utils.atoms_util.convert_atoms_to_upper()`."
#     140     )
# --> 142 self.init_time = atoms.info["total_time"]
#     143 self.init_step = atoms.info["total_step"]
#     145 self._extensions: MDExtensionList = []
#
# KeyError: 'total_time'

# %%
def set_interface_fixed_atoms_uniform_free(atoms, target_free_thickness=36.0):
    """界面構造で自由領域の厚みを統一する固定原子設定
    
    Parameters:
    -----------
    atoms : ase.Atoms
        対象の原子構造
    target_free_thickness : float
        自由領域の目標厚さ（Å）
        
    Returns:
    --------
    atoms : ase.Atoms
        固定制約が設定された原子構造
    """
    positions = atoms.get_positions()
    z_coords = positions[:, 2]
    z_min, z_max = np.min(z_coords), np.max(z_coords)
    total_thickness = z_max - z_min
    
    print(f"自由領域統一固定層設定:")
    print(f"  総材料厚さ: {total_thickness:.2f}Å")
    print(f"  目標自由領域厚さ: {target_free_thickness:.2f}Å")
    
    # 界面情報を取得
    interface_info = identify_interface_region(atoms)
    
    if interface_info['is_interface']:
        print(f"  界面構造検出: 界面位置 = {interface_info['interface_z']:.2f}Å")
        print(f"  Al領域: {interface_info['al_region'][0]:.2f} - {interface_info['al_region'][1]:.2f}Å")
        print(f"  NMC領域: {interface_info['nmc_region'][0]:.2f} - {interface_info['nmc_region'][1]:.2f}Å")
        
        # 界面中心を基準に自由領域を設定
        interface_z = interface_info['interface_z']
        free_half_thickness = target_free_thickness / 2.0
               # 自由領域の範囲
        free_z_min = interface_z - free_half_thickness
        free_z_max = interface_z + free_half_thickness
        
        # 材料範囲内に調整
        free_z_min = max(free_z_min, z_min + 2.0)  # 最低2Å下は固定
        free_z_max = min(free_z_max, z_max - 2.0)  # 最低2Å上は固定
        
        actual_free_thickness = free_z_max - free_z_min
        
        print(f"  自由領域: {free_z_min:.2f} - {free_z_max:.2f}Å")
        print(f"  実際の自由領域厚さ: {actual_free_thickness:.2f}Å")
        
        # 固定原子の選択（自由領域外を固定）
        indices = [
            i for i, z in enumerate(z_coords)
            if z < free_z_min or z > free_z_max
        ]
        
    else:
        # 非界面構造の場合：中心を基準に自由領域を設定
        print(f"  非界面構造: 中心基準で自由領域設定")
        center_z = (z_min + z_max) / 2.0
        free_half_thickness = target_free_thickness / 2.0
        
        free_z_min = max(center_z - free_half_thickness, z_min + 2.0)
        free_z_max = min(center_z + free_half_thickness, z_max - 2.0)
        
        actual_free_thickness = free_z_max - free_z_min
        
        print(f"  中心位置: {center_z:.2f}Å")
        print(f"  自由領域: {free_z_min:.2f} - {free_z_max:.2f}Å")
        print(f"  実際の自由領域厚さ: {actual_free_thickness:.2f}Å")
        
        # 固定原子の選択     
        indices = [
            i for i, z in enumerate(z_coords)
            if z < free_z_min or z > free_z_max
        ]
    
        # 固定制約の設定
        if len(indices) == 0:
            print("  警告: 固定原子がありません")
            return atoms
        
        constraint = FixAtoms(indices=indices)
        atoms.set_constraint(constraint)
        
        # 統計情報
        free_atoms = len(atoms) - len(indices)
        free_ratio = free_atoms / len(atoms)
        fixed_ratio = len(indices) / len(atoms)
        
        print(f"  固定原子数: {len(indices)}/{len(atoms)} ({fixed_ratio*100:.1f}%)")
        print(f"  自由原子数: {free_atoms}/{len(atoms)} ({free_ratio*100:.1f}%)")
        
        # 構造情報を属性として保存
        atoms.info['free_region_thickness'] = actual_free_thickness
        atoms.info['free_region_bounds'] = (free_z_min, free_z_max)
        atoms.info['fixed_atoms_count'] = len(indices)
        atoms.info['free_atoms_count'] = free_atoms
    
    return atoms

# %%
system.ase_atoms.get_stress()
# Out:
# ---------------------------------------------------------------------------
# PropertyNotImplementedError               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 system.ase_atoms.get_stress()
#
# File ~/.py311/lib/python3.11/site-packages/ase/atoms.py:861, in Atoms.get_stress(self, voigt, apply_constraint, include_ideal_gas)
#     858 if self._calc is None:
#     859     raise RuntimeError('Atoms object has no calculator.')
# --> 861 stress = self._calc.get_stress(self)
#     862 shape = stress.shape
#     864 if shape == (3, 3):
#     865     # Convert to the Voigt form before possibly applying
#     866     # constraints and adding the dynamic part of the stress
#     867     # (the "ideal gas contribution").
#
# File ~/.py311/lib/python3.11/site-packages/ase/calculators/abc.py:35, in GetPropertiesMixin.get_stress(self, atoms)
#      34 def get_stress(self, atoms=None):
# ---> 35     return self.get_property('stress', atoms)
#
# File ~/.py311/lib/python3.11/site-packages/ase/calculators/calculator.py:520, in BaseCalculator.get_property(self, name, atoms, allow_calculation)
#     515     self.calculate(atoms, [name], system_changes)
#     517 if name not in self.results:
#     518     # For some reason the calculator was not able to do what we want,
#     519     # and that is OK.
# --> 520     raise PropertyNotImplementedError(
#     521         '{} not present in this ' 'calculation'.format(name)
#     522     )
#     524 result = self.results[name]
#     525 if isinstance(result, np.ndarray):
#
# PropertyNotImplementedError: stress not present in this calculation

# %%
import ase
from ase.build import bulk
from ase.md.velocitydistribution import MaxwellBoltzmannDistribution,Stationary
from ase.md.npt import NPT
from ase.md import MDLogger
from ase import units
from time import perf_counter

calc_type = "EMT"
# calc_type = "PFP"

if calc_type == "EMT":
    # ASAP3-EMT calculator
    from asap3 import EMT
    calculator = EMT()
elif calc_type == "PFP":
    # PFP calculator
    from pfp_api_client.pfp.estimator import Estimator, EstimatorCalcMode
    from pfp_api_client.pfp.calculators.ase_calculator import ASECalculator
    estimator = Estimator(model_version="v2.0.0",calc_mode=EstimatorCalcMode.CRYSTAL_U0)
    calculator = ASECalculator(estimator)
else:
    raise ValueError(f"Wrong calc_type = {calc_type}!")


# Set up a crystal
atoms_in = bulk("Cu",cubic=True)
atoms_in *= 3
atoms_in.pbc = True
print("atoms_in = ",atoms_in)

# input parameters
time_step    = 1.0    # fsec
#temperature = 300    # Kelvin
num_md_steps = 20000 
num_interval = 10

sigma   = 1.0     # External pressure in bar
ttime   = 20.0    # Time constant in fs
pfactor = 2e6     # Barostat parameter in GPa
temperature_list = [200,300,400,500,600,700,800,900,1000]

# Print statements
def print_dyn():
    imd = dyn.get_number_of_steps()
    etot  = atoms.get_total_energy()
    temp_K = atoms.get_temperature()
    stress = atoms.get_stress(include_ideal_gas=True)/units.GPa
    stress_ave = (stress[0]+stress[1]+stress[2])/3.0 
    elapsed_time = perf_counter() - start_time
    print(f"  {imd: >3}   {etot:.3f}    {temp_K:.2f}    {stress_ave:.2f}  {stress[0]:.2f}  {stress[1]:.2f}  {stress[2]:.2f}  {stress[3]:.2f}  {stress[4]:.2f}  {stress[5]:.2f}    {elapsed_time:.3f}")

    
# run MD
for i,temperature in enumerate(temperature_list):
    print("i,temperature = ",i,temperature)

    print(f"sigma = {sigma:.1e} bar")
    print(f"ttime = {ttime:.3f} fs")
    print(f"pfactor = {pfactor:.3f} GPa*fs^2")

    temperature_str = str(int(temperature)).zfill(4)
    output_filename = f"./output/ch6/fcc-Cu_3x3x3_NPT_{calc_type}_{temperature_str}K"
    log_filename = output_filename + ".log"
    traj_filename = output_filename + ".traj"
    print("log_filename = ",log_filename)
    print("traj_filename = ",traj_filename)
    
    atoms = atoms_in.copy()
    atoms.calc = calculator
    
    # Set the momenta corresponding to T=300K
    MaxwellBoltzmannDistribution(atoms, temperature_K=temperature,force_temp=True)
    Stationary(atoms)
    
    dyn = NPT(atoms,
          time_step*units.fs,
          temperature_K = temperature,
          externalstress = sigma*units.bar,
          ttime = ttime*units.fs,
          pfactor = pfactor*units.GPa*(units.fs**2),
          logfile = log_filename,
          trajectory = traj_filename,
          loginterval=num_interval
          )
    
    print_interval = 1000 if calc_type == "EMT" else num_interval
    dyn.attach(print_dyn, interval=print_interval)
    dyn.attach(MDLogger(dyn, atoms, log_filename, header=True, stress=True, peratom=True, mode="a"), interval=num_interval)

    # Now run the dynamics
    start_time = perf_counter()
    print(f"    imd     Etot(eV)    T(K)    stress(mean,xx,yy,zz,yz,xz,xy)(GPa)  elapsed_time(sec)")
    dyn.run(num_md_steps)

# %%
# from pfp_estimator.core import pfp_estimator_fn
# from pfp_estimator.estimator import EstimatorCalcMode
# from pfp_estimator.features import MDFeature
# from openmm import LangevinIntegrator

# Assuming `system` is already defined (e.g., from an OpenMM setup)
# and `equil_file` is the desired trajectory file name prefix.
atoms=read("pvdf_opt.xyz")
# system=MatlantisAtoms.from_ase_atoms(atoms)
# Define the list of calculation modes you want to run.
calc_modes_to_run = [
    'pbe',
    'pbe_plus_d3',
    'wb97xd',
    'MOLECULE',
    'crystal',
    'crystal_u0_plus_d3'
]
# set_interface_fixed_atoms_uniform_free(system,)
# Create the integrator
atoms = MatlantisAtoms.from_ase_atoms(atoms)
system = ASEMDSystem(atoms)
integrator = LangevinIntegrator(timestep=1.0, temperature=900.0)

# Loop through each calculation mode
for mode_str in calc_modes_to_run:
    print(f"Starting simulation with calc_mode: {mode_str}")

    # Instantiate the estimator function for the current mode
    estimator_fn = pfp_estimator_fn(model_version='v7.0.0', calc_mode=mode_str)

    # Create the MD feature with the new estimator function
    md = MDFeature(
        integrator,
        n_run=4000,
        traj_file_name=f"pvdfcalc_{mode_str}.traj",
        traj_freq=100,
        estimator_fn=estimator_fn
    )

    # Run the MD simulation
    md(system)
    print(f"Simulation with {mode_str} completed.")
# Out:
# The MD trajectory will be saved at /home/jovyan/Kaori/MD/LiB_2/structure/pvdfcalc_crystal_u0_plus_d3.traj.
# Note: The max disk size of /home/jovyan is about 98G.
# Starting simulation with calc_mode: crystal_u0_plus_d3
# ---------------------------------------------------------------------------
# PropertyNotImplementedError               Traceback (most recent call last)
# Cell In[21], line 40
#      31 md = MDFeature(
#      32     integrator,
#      33     n_run=4000,
#    (...)
#      36     estimator_fn=estimator_fn
#      37 )
#      39 # Run the MD simulation
# ---> 40 md(system)
#      41 print(f"Simulation with {mode_str} completed.")
#
# File ~/.py311/lib/python3.11/site-packages/matlantis_features/features/base.py:131, in FeatureBaseCaller.call_decorate.<locals>.decorated(self, *args, **kwargs)
#     129 args_list = [copy_to_child_conversion(arg) for arg in args]
#     130 kwargs_new = {k: copy_to_child_conversion(v) for k, v in kwargs.items()}
# --> 131 res = derived_call(self, *args_list, **kwargs_new)
#     132 return res
#
# File ~/.py311/lib/python3.11/site-packages/matlantis_features/features/md/md.py:353, in MDFeature.__call__(self, system, extensions)
#     345     trajw = ASETrajWriter(
#     346         file_name=traj_fname,
#     347         write_mode=self.traj_write_mode,
#     348         props=self.traj_props,
#     349         save_init_frame=self.traj_init_frame,
#     350     )
#     351     sim.append_extension(trajw, self.traj_freq)
# --> 353 sim.run(n_run_steps=self.n_run)
#     355 if trajw is not None:
#     356     trajw.close()
#
# File ~/.py311/lib/python3.11/site-packages/matlantis_features/features/md/ase_simulation.py:192, in ASESimulation.run(self, n_run_steps)
#     187 if isinstance(self.integrator, NPTIntegrator):
#     188     # The ase.md.npt.NPT does not call the observers at step==0.
#     189     # To keep consistency with the other dynamics obj, we add the following line.
#     190     dyn.call_observers()
# --> 192 dyn.run(steps=n_run_steps)
#
# File ~/.py311/lib/python3.11/site-packages/ase/md/md.py:171, in MolecularDynamics.run(self, steps)
#     158 def run(self, steps=50):
#     159     """Run molecular dynamics algorithm.
#     160
#     161     Parameters
#    (...)
#     169         True if the maximum number of steps are reached.
#     170     """
# --> 171     return Dynamics.run(self, steps=steps)
#
# File ~/.py311/lib/python3.11/site-packages/ase/optimize/optimize.py:286, in Dynamics.run(self, steps)
#     268 def run(self, steps=DEFAULT_MAX_STEPS):
#     269     """Run dynamics algorithm.
#     270
#     271     This method will return when the forces on all individual
#    (...)
#     283         True if the forces on atoms are converged.
#     284     """
# --> 286     for converged in Dynamics.irun(self, steps=steps):
#     287         pass
#     288     return converged
#
# File ~/.py311/lib/python3.11/site-packages/ase/optimize/optimize.py:262, in Dynamics.irun(self, steps)
#     260 # log the step
#     261 self.log()
# --> 262 self.call_observers()
#     264 # check convergence
#     265 is_converged = self.converged()
#
# File ~/.py311/lib/python3.11/site-packages/ase/optimize/optimize.py:207, in Dynamics.call_observers(self)
#     205         call = True
#     206 if call:
# --> 207     function(*args, **kwargs)
#
# File ~/.py311/lib/python3.11/site-packages/matlantis_features/features/md/ase_simulation.py:67, in ASETrajWriter.__call__(self, system, integrator)
#      63     return
#      64 logger.debug(
#      65     f"Traj step: {istep}({atoms.info['total_step']}) x0: {atoms.get_positions()[0]}"
#      66 )
# ---> 67 self.traj.write(atoms)
#
# File ~/.py311/lib/python3.11/site-packages/ase/io/trajectory.py:149, in TrajectoryWriter.write(self, atoms, **kwargs)
#     146     atoms = self.atoms
#     148 for image in atoms.iterimages():
# --> 149     self._write_atoms(image, **kwargs)
#
# File ~/.py311/lib/python3.11/site-packages/ase/io/trajectory.py:193, in TrajectoryWriter._write_atoms(self, atoms, **kwargs)
#     191 if self.properties is not None:
#     192     if prop in self.properties:
# --> 193         x = calc.get_property(prop, atoms)
#     194     else:
#     195         x = None
#
# File ~/.py311/lib/python3.11/site-packages/ase/calculators/calculator.py:520, in BaseCalculator.get_property(self, name, atoms, allow_calculation)
#     515     self.calculate(atoms, [name], system_changes)
#     517 if name not in self.results:
#     518     # For some reason the calculator was not able to do what we want,
#     519     # and that is OK.
# --> 520     raise PropertyNotImplementedError(
#     521         '{} not present in this ' 'calculation'.format(name)
#     522     )
#     524 result = self.results[name]
#     525 if isinstance(result, np.ndarray):
#
# PropertyNotImplementedError: stress not present in this calculation

# %%
import matlantis_features
help(matlantis_features.features.md.MDFeature)
# Out:
# Help on class MDFeature in module matlantis_features.features.md.md:
#
# class MDFeature(matlantis_features.features.base.FeatureBase)
#  |  MDFeature(integrator: matlantis_features.features.md.md_integrator_base.MDIntegratorBase, n_run: int, checkpoint_file_name: Optional[str] = None, checkpoint_freq: Optional[int] = 10, traj_file_name: Optional[str] = None, traj_freq: Optional[int] = 1, traj_props: Optional[List[str]] = None, traj_append: bool = False, traj_init_frame: bool = False, show_progress_bar: bool = False, tqdm_options: Optional[Dict[str, Any]] = None, show_logger: bool = False, logger_interval: int = 100, estimator_fn: Optional[Callable[[], pfp_api_client.pfp.estimator.Estimator]] = None)
#  |
#  |  The matlantis-feature for molecular dynamics simulation.
#  |
#  |  Method resolution order:
#  |      MDFeature
#  |      matlantis_features.features.base.FeatureBase
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __call__ = decorated(self, system: matlantis_features.features.md.md_system_base.MDSystemBase, extensions: Optional[List[Tuple[matlantis_features.features.md.md_extensions.MDExtensionBase, int]]] = None) -> matlantis_features.features.md.md.MDFeatureResult from matlantis_features.features.base.FeatureBaseCaller.call_decorate.<locals>
#  |      Run the MD simulation.
#  |
#  |      Args:
#  |          system (MDSystemBase):
#  |            Target system of the MD simulation.
#  |          extensions (MDExtensionList or None, optional):
#  |            Extension list (tuple of extension object and interval) used for the simulation.
#  |            Defaults to None.
#  |      Returns:
#  |          MDFeatureResult : Result object for the MD simulation.
#  |
#  |  __init__(self, integrator: matlantis_features.features.md.md_integrator_base.MDIntegratorBase, n_run: int, checkpoint_file_name: Optional[str] = None, checkpoint_freq: Optional[int] = 10, traj_file_name: Optional[str] = None, traj_freq: Optional[int] = 1, traj_props: Optional[List[str]] = None, traj_append: bool = False, traj_init_frame: bool = False, show_progress_bar: bool = False, tqdm_options: Optional[Dict[str, Any]] = None, show_logger: bool = False, logger_interval: int = 100, estimator_fn: Optional[Callable[[], pfp_api_client.pfp.estimator.Estimator]] = None)
#  |      Initialize an instance.
#  |
#  |      Args:
#  |          integrator (MDIntegratorBase): Integrator object used for the simulation.
#  |          n_run (int): Number or the steps to be run.
#  |          checkpoint_file_name (str or None, optional):
#  |            Checkpoint file name. If this value is None and checkpoint_freq>0,
#  |            checkpoint file name is automatically generated.
#  |            If relative path name is given,
#  |            the file is stored in the current working directory.
#  |            Defaults to None.
#  |          checkpoint_freq (int or None, optional):
#  |            Checkpoint creation frequency.
#  |            If this value is None or non positive, no checkpoit file is created.
#  |            Defaults to 10.
#  |          traj_file_name (str or None, optional):
#  |            Trajectory file name. If this value is None and traj_freq>0,
#  |            trajectory file name is automatically generated.
#  |            If relative path name is given,
#  |            the file is stored in the current working directory.
#  |            Defaults to None.
#  |          traj_freq (int or None, optional):
#  |            Trajectory saving frequency.
#  |            If this value is None or non positive, no trajectory file is created.
#  |            Defaults to 1.
#  |          traj_props (list[str] or None, optional):
#  |            Names of the properties stored in the trajectory file.
#  |            If None, energy, forces, and stress properties are stored.
#  |            Defaults to None.
#  |          traj_append (bool, optional):
#  |            If True and trajectory file exists, trajectory will be
#  |            appended to the existing file. Defaults to False.
#  |          traj_init_frame (bool, optional):
#  |            If True, the initial structure of the simulation is
#  |            also stored in the trajectory file. Defaults to False.
#  |          show_progress_bar (bool, optional): Show progress bar. Defaults to False.
#  |          tqdm_options (dict[str, Any] or None, optional): Options for tqdm.
#  |          show_logger (bool, optional): Show log information. Defaults to False.
#  |          logger_interval (int, optional):
#  |              The interval of when to print out logger information.
#  |              Defaults to 100.
#  |          estimator_fn (EstimatorFnType or None, optional):
#  |              A factory method to create a custom estimator.
#  |              Please refer :ref:`custom_estimator` for detail.
#  |
#  |  get_temp_dir(self) -> pathlib.Path
#  |      Create temperory directory.
#  |
#  |      Returns:
#  |          Path : The location of temperory directory.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from matlantis_features.features.base.FeatureBase:
#  |
#  |  __setattr__(self, name: str, value: Any) -> None
#  |      Set attribution of the feature.
#  |
#  |      Args:
#  |          name (str): The name of attribution.
#  |          value (Any): The value of the attribution.
#  |
#  |  attach_ctx(self, ctx: Optional[matlantis_features.utils.context.Context] = None) -> None
#  |      Attach the feature to matlantis_features.utils.Context.
#  |
#  |      Args:
#  |          ctx (Context or None, optional): The matlantis_features.utils.Context object. Defaults to None.
#  |
#  |  check_estimator_fn(self, estimator_fn: Optional[Callable[[], pfp_api_client.pfp.estimator.Estimator]]) -> None
#  |      Checks if the given estimator function is None and output a warning if so.
#  |
#  |      Args:
#  |          estimator_fn (EstimatorFnType or None, optional):
#  |              A factory method to create a custom estimator.
#  |              Please refer :ref:`custom_estimator` for detail. Defaults to None.
#  |
#  |  cost_estimate(self, atoms: Union[ase.atoms.Atoms, matlantis_features.atoms.MatlantisAtoms, NoneType] = None) -> matlantis_features.utils.context.FeatureCost
#  |      Estimate the cost of the feature.
#  |
#  |      Args:
#  |          atoms (ASEAtoms or MatlantisAtoms or None, optional):
#  |            The input atoms. Defaults to None.
#  |      Returns:
#  |          FeatureCost : The cost of the feature.
#  |
#  |  get_savedir_from_ctx(self) -> pathlib.Path
#  |      Get the temporary save directory from the context.
#  |
#  |      Returns:
#  |          pathlib.Path : The temporary save directory .
#  |
#  |  init_scope(self) -> Iterator[NoneType]
#  |      Context manager that enable to set attribution of the feature.
#  |
#  |      Returns:
#  |          Iterator[None] : Init_scope context manager.
#  |
#  |  repeat(self: ~Self, n_repeat: int) -> ~Self
#  |      Set the maximum number of times that allowed to run the __call__ function.
#  |
#  |      Args:
#  |          n_repeat (int): The maximum number of repeats.
#  |      Returns:
#  |          Self : The feature.
#  |
#  |  to_dict(self) -> Dict[str, Any]
#  |      Dictionary representation of the FeatureBase.
#  |
#  |      Returns:
#  |          dict[str, Any] : A dict containing a serialized FeatureBase.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from matlantis_features.features.base.FeatureBase:
#  |
#  |  from_dict(res: Dict[str, Any]) -> 'FeatureBase'
#  |      Construct a FeatureBase object from serialized dict.
#  |
#  |      Args:
#  |          res (dict[str, Any]): A dict containing a serialized FeatureBase from to_dict().
#  |      Returns:
#  |          FeatureBase : The deserialized object from provided dict.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from matlantis_features.features.base.FeatureBase:
#  |
#  |  n_repeat
#  |      Get the maximum number of times that allowed to run the __call__ function.
#  |
#  |      Returns:
#  |          int : The maximum number of repeats.
#  |
#  |  registered
#  |      Check whether the feature is registered or attached.
#  |
#  |      Returns:
#  |          bool : Whether the feature is registered or attached..
#  |
#  |  total_name
#  |      The total name of the feature which is the combination of         own name and parent feature's name.
#  |
#  |      Returns:
#  |          str : The total name of the feature.
#  |
#  |  within_init_scope
#  |      Check whether or not in the init_scope.
#  |
#  |      Returns:
#  |          bool : Whether or not in the init_scope.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from matlantis_features.features.base.FeatureBase:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  name
#  |      The name of the feature.
#  |
#  |      Returns:
#  |          str : The name of the feature.

# %%
help(EstimatorCalcMode)
# Out:
# Help on class EstimatorCalcMode in module pfp_api_client.pfp.estimator:
#
# class EstimatorCalcMode(enum.Enum)
#  |  EstimatorCalcMode(value, names=None, *, module=None, qualname=None, type=None, start=1, boundary=None)
#  |
#  |  Enum class which is used to determine `calc_mode` in `Estimator`.
#  |
#  |  :ivar PBE: This mode corresponds to DFT calculations with plane wave basis sets.
#  |  :ivar PBE_PLUS_D3: PBE mode with D3 correction enabled.     This mode corresponds to DFT calculations with plane wave basis sets,     plus a D3 dispersion correction.
#  |  :ivar PBE_U: PBE mode with Hubbard U parameter. This mode corresponds      to DFT calculations with plane wave basis sets.
#  |  :ivar PBE_U_PLUS_D3: PBE_U mode with D3 correction enabled.     This mode corresponds to DFT calculations with plane wave basis sets,     plus a D3 dispersion correction.
#  |  :ivar WB97XD: This mode corresponds to DFT calculations with local basis     sets.
#  |
#  |  Method resolution order:
#  |      EstimatorCalcMode
#  |      enum.Enum
#  |      builtins.object
#  |
#  |  Data and other attributes defined here:
#  |
#  |  CRYSTAL = <EstimatorCalcMode.CRYSTAL: 'crystal'>
#  |
#  |  CRYSTAL_PLUS_D3 = <EstimatorCalcMode.CRYSTAL_PLUS_D3: 'crystal_plus_d3...
#  |
#  |  CRYSTAL_U0 = <EstimatorCalcMode.CRYSTAL_U0: 'crystal_u0'>
#  |
#  |  CRYSTAL_U0_PLUS_D3 = <EstimatorCalcMode.CRYSTAL_U0_PLUS_D3: 'crystal_u...
#  |
#  |  MOLECULE = <EstimatorCalcMode.MOLECULE: 'molecule'>
#  |
#  |  PBE = <EstimatorCalcMode.PBE: 'pbe'>
#  |
#  |  PBE_PLUS_D3 = <EstimatorCalcMode.PBE_PLUS_D3: 'pbe_plus_d3'>
#  |
#  |  PBE_U = <EstimatorCalcMode.PBE_U: 'pbe_u'>
#  |
#  |  PBE_U_PLUS_D3 = <EstimatorCalcMode.PBE_U_PLUS_D3: 'pbe_u_plus_d3'>
#  |
#  |  R2SCAN = <EstimatorCalcMode.R2SCAN: 'r2scan'>
#  |
#  |  R2SCAN_PLUS_D3 = <EstimatorCalcMode.R2SCAN_PLUS_D3: 'r2scan_plus_d3'>
#  |
#  |  WB97XD = <EstimatorCalcMode.WB97XD: 'wb97xd'>
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from enum.Enum:
#  |
#  |  name
#  |      The name of the Enum member.
#  |
#  |  value
#  |      The value of the Enum member.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from enum.EnumType:
#  |
#  |  __contains__(member)
#  |      Return True if member is a member of this enum
#  |      raises TypeError if member is not an enum member
#  |
#  |      note: in 3.12 TypeError will no longer be raised, and True will also be
#  |      returned if member is the value of a member in this enum
#  |
#  |  __getitem__(name)
#  |      Return the member matching `name`.
#  |
#  |  __iter__()
#  |      Return members in definition order.
#  |
#  |  __len__()
#  |      Return the number of members (no aliases)
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from enum.EnumType:
#  |
#  |  __members__
#  |      Returns a mapping of member name->value.
#  |
#  |      This mapping lists all enum members, including aliases. Note that this
#  |      is a read-only view of the internal mapping.

# %%
integrator = LangevinIntegrator(timestep=1.0, temperature=300.0)
                                md = MDFeature(integrator, n_run=3000, traj_file_name=equil_file, traj_freq=100, estimator_fn=estimator_fn)
                                md(system)
