# %%
# !du -ah . | sort -rh | head -n 20
# Out:
# 39G	.
# 30G	./output
# 18G	./output/final_interfaces
# 12G	./output/opt_traj
# 2.8G	./MD_miller
# 1.5G	./MD4
# 1.4G	./MD_miller/tensile01
# 1.4G	./MD3
# 1.2G	./MD_P0
# 1010M	./MD_miller/heat
# 767M	./MD3/tensile
# 583M	./MD4/tensile01
# 583M	./MD4/tensile
# 559M	./MD_P0/tensile1
# 439M	./MD3/heat
# 419M	./pvdf_big222_water_600K.traj
# 419M	./pvdf_big222_water_500K.traj
# 397M	./pvdf_water_random2_600K.traj
# 385M	./MD_miller/error_files
# 369M	./MD_P0/heat
# sort: write failed: 'standard output': Broken pipe
# sort: write error
